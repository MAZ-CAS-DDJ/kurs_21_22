# %% [markdown]
# # APIs, Libraries, Modules -> "Requests"
# Gezielt und automatisiert Daten im Web auslesen

# %% [markdown]
# Die Python-Library erlaubt es, automatisiert URLs zu besuchen und gezielt Inhalte herauszulesen. Der Untertitel in [der Dokumentation](http://docs.python-requests.org/en/master/) fasst eigentlich am besten zusammen, was ```requests``` ist: "HTTP for Humans." HTTP steht für Hyper Text Transfer Protocol und ist die Technologie, die Tim Berners-Lee im Jahr 1990 erfunden hat. Ohne HTTP kein Internet. Mit ```Requests```können wir Websites viel genauer befragen, als wir das mit Wget letzte Woche kennengelernt haben.

# %% [markdown]
# ### Unsere Imports

# %%
import requests
import pandas as pd #diese Library werdet ihr am Mittwoch und Donnerstag viel genauer anschauen

# %% [markdown]
# Zur Dokumentation von ```requests``` geht es [hier lang](http://docs.python-requests.org/en/master/).

# %% [markdown]
# ### Notes

# %% [markdown]
# In einer ersten Übung arbeiten wir mit [der API des USGS](https://earthquake.usgs.gov/fdsnws/event/1/#methods) arbeiten. Für die meisten API muss man sich heutezutage eine eigene API-Key kreieren. Doch diese API braucht keine Keys. Deshalb ist es ein gutes Kennenlernbeispiel.

# %% [markdown]
# Falls Probleme mit dem Output auftauchen, hier ein Work around für die Meldung, dass der Output limitiert wurde. [Reconfigure line output](https://stackoverflow.com/questions/43288550/iopub-data-rate-exceeded-when-viewing-image-in-jupyter-notebook) and [opening stuff from the command line](https://stackoverflow.com/questions/16344709/how-to-open-a-file-from-the-command-line-with-a-specified-program)

# %% [markdown]
# ### Dokumentation

# %% [markdown]
# Bevor man mit deiner API arbeitet, lohnt es sich immer zuerst, die [Dokumentation](https://earthquake.usgs.gov/fdsnws/event/1/#parameters) anzuschauen.

# %% [markdown]
# ### Erste Abfragen

# %% [markdown]
# Kleinere Abfrage. Wieviele Erdbeben hat es in einem bestimmten Zeitraum gegeben?

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '148029'

# %% [markdown]
# Wieviele hat es letzte Nacht von x bis x gegeben? Dafür müssen wir in der Dokumentation Time nachfragen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2020-01-01&endtime=2020-09-30'

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '148029'

# %% [markdown]
# Wegen Zeitverschiebung Zeit anpassen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2020-01-01T24:00:00&endtime=2020-09-30T08:00:00'

# %%
response = requests.get(url)
response.text
# Out:
# '147551'

# %% [markdown]
# ### Grosse, komibinierte Abfrage

# %% [markdown]
# Details zu allen Erbeben in den über drei Tage, 18-7-2017 bis 31-7-2017.

# %%
url1 = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson'

# %%
urlzeit = '&starttime=2020-09-01&endtime=2020-09-27'

# %%
url1 + urlzeit
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-09-01&endtime=2020-09-27'

# %%
response = requests.get(url1 + urlzeit)

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1631521608000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-09-01&endtime=2020-09-27',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.12.2',
#   'count': 11911},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '35 km SW of Skwentna, Alaska',
#     'time': 1601164494641,
#     'updated': 1602044222011,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cex4dfg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cex4dfg&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '020cex4dfg',
#     'ids': ',ak020cex4dfg,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.43,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 35 km SW of Skwentna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.791, 61.7286, 95.1]},
#    'id': 'ak020cex4dfg'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '106 km ESE of Honiara, Solomon Islands',
#     'time': 1601164436670,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1sm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1sm&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000c1sm',
#     'ids': ',us6000c1sm,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.954,
#     'rms': 0.55,
#     'gap': 96,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 106 km ESE of Honiara, Solomon Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [160.8021, -9.8904, 10]},
#    'id': 'us6000c1sm'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '29 km SSE of Mina, Nevada',
#     'time': 1601164338360,
#     'updated': 1601169929304,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775864',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775864&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00775864',
#     'ids': ',nn00775864,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.032,
#     'rms': 0.1,
#     'gap': 156.87,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 29 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0058, 38.138, 0]},
#    'id': 'nn00775864'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '18 km N of Igiugig, Alaska',
#     'time': 1601164330772,
#     'updated': 1602044221746,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cex3uan',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cex3uan&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '020cex3uan',
#     'ids': ',ak020cex3uan,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.75,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 18 km N of Igiugig, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.8457, 59.4896, 14.5]},
#    'id': 'ak020cex3uan'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '44 km SSE of Adak, Alaska',
#     'time': 1601164167101,
#     'updated': 1602044221477,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cex38ex',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cex38ex&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '020cex38ex',
#     'ids': ',ak020cex38ex,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.37,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 44 km SSE of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-176.3563, 51.5154, 30.6]},
#    'id': 'ak020cex38ex'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '62 km ENE of Pedro Bay, Alaska',
#     'time': 1601164013934,
#     'updated': 1602044222259,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cex2nch',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cex2nch&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '020cex2nch',
#     'ids': ',ak020cex2nch,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.17,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 62 km ENE of Pedro Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.0771, 59.9983, 111.2]},
#    'id': 'ak020cex2nch'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'Pacific-Antarctic Ridge',
#     'time': 1601163901555,
#     'updated': 1607202190040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c3wa',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c3wa&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000c3wa',
#     'ids': ',us6000c3wa,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 25.587,
#     'rms': 0.82,
#     'gap': 90,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - Pacific-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.3174, -57.4625, 10]},
#    'id': 'us6000c3wa'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '4 km SSW of La Parguera, Puerto Rico',
#     'time': 1601163254220,
#     'updated': 1601164927356,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020270025',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020270025&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'pr',
#     'code': '2020270025',
#     'ids': ',pr2020270025,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.0424,
#     'rms': 0.1,
#     'gap': 237,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 4 km SSW of La Parguera, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0725, 17.9378, 11]},
#    'id': 'pr2020270025'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '51 km SE of King Cove, Alaska',
#     'time': 1601163194231,
#     'updated': 1602044221225,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewzrxm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewzrxm&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '020cewzrxm',
#     'ids': ',ak020cewzrxm,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.23,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 51 km SE of King Cove, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-161.7044, 54.7683, 46.6]},
#    'id': 'ak020cewzrxm'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '29 km SSE of Mina, Nevada',
#     'time': 1601163133095,
#     'updated': 1601319781953,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775860',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775860&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'nn',
#     'code': '00775860',
#     'ids': ',nn00775860,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.033,
#     'rms': 0.1243,
#     'gap': 89.94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 29 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0008, 38.1369, 2]},
#    'id': 'nn00775860'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '74 km ESE of Ruby, Alaska',
#     'time': 1601162841508,
#     'updated': 1602044220955,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewyi8e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewyi8e&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '020cewyi8e',
#     'ids': ',ak020cewyi8e,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.88,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 74 km ESE of Ruby, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.0465, 64.4912, 6.4]},
#    'id': 'ak020cewyi8e'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '38 km WNW of Beluga, Alaska',
#     'time': 1601162776006,
#     'updated': 1602044220669,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewya3o',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewya3o&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '020cewya3o',
#     'ids': ',ak020cewya3o,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.44,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 38 km WNW of Beluga, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.7567, 61.2454, 80.9]},
#    'id': 'ak020cewya3o'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '36 km SE of Mina, Nevada',
#     'time': 1601162726760,
#     'updated': 1601163169072,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775859',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775859&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00775859',
#     'ids': ',nn00775859,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.063,
#     'rms': 0.07,
#     'gap': 120.81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 36 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.7882, 38.1765, 10.1]},
#    'id': 'nn00775859'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.57,
#     'place': '14km ESE of Mammoth Lakes, CA',
#     'time': 1601162684590,
#     'updated': 1601166483223,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463211',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463211&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'nc',
#     'code': '73463211',
#     'ids': ',nc73463211,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.01423,
#     'rms': 0.05,
#     'gap': 164,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 14km ESE of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.8313333, 37.6041667, 5.21]},
#    'id': 'nc73463211'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '36 km SE of Mina, Nevada',
#     'time': 1601162526330,
#     'updated': 1601162814315,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775855',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775855&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'nn',
#     'code': '00775855',
#     'ids': ',nn00775855,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.041,
#     'rms': 0.17,
#     'gap': 69.64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 36 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8227, 38.1453, 9.6]},
#    'id': 'nn00775855'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.15,
#     'place': '5km E of Mammoth Lakes, CA',
#     'time': 1601162399770,
#     'updated': 1601174523506,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463201',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463201&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 71,
#     'net': 'nc',
#     'code': '73463201',
#     'ids': ',nc73463201,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 26,
#     'dmin': 0.01768,
#     'rms': 0.04,
#     'gap': 53,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 5km E of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.922, 37.6351667, 5.47]},
#    'id': 'nc73463201'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '40 km SE of Mina, Nevada',
#     'time': 1601162360010,
#     'updated': 1601162590583,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775852',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775852&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00775852',
#     'ids': ',nn00775852,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.051,
#     'rms': 0.06,
#     'gap': 113.69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 40 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.7402, 38.1697, 10.5]},
#    'id': 'nn00775852'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.7,
#     'place': '36 km SE of Denali National Park, Alaska',
#     'time': 1601162327471,
#     'updated': 1602044220420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewwmnw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewwmnw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'ak',
#     'code': '020cewwmnw',
#     'ids': ',ak020cewwmnw,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.7,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 36 km SE of Denali National Park, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2354, 63.2986, 8.6]},
#    'id': 'ak020cewwmnw'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.25,
#     'place': '6km S of Livermore, CA',
#     'time': 1601162274820,
#     'updated': 1601511785052,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463206',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463206&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'nc',
#     'code': '73463206',
#     'ids': ',nc73463206,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 16,
#     'dmin': 0.006534,
#     'rms': 0.08,
#     'gap': 67,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 6km S of Livermore, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.7626667, 37.6268333, 3]},
#    'id': 'nc73463206'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.74,
#     'place': '21km ENE of San Ardo, CA',
#     'time': 1601162230490,
#     'updated': 1601675526272,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463196',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463196&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '73463196',
#     'ids': ',nc73463196,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 16,
#     'dmin': 0.03872,
#     'rms': 0.07,
#     'gap': 162,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 21km ENE of San Ardo, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-120.684, 36.0881667, 5.94]},
#    'id': 'nc73463196'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.01,
#     'place': '8 km ENE of P?hala, Hawaii',
#     'time': 1601162210700,
#     'updated': 1601162542090,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72154416',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv72154416&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'hv',
#     'code': '72154416',
#     'ids': ',hv72154416,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 115,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 8 km ENE of P?hala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.411331176758, 19.2388324737549, 31.8600006103516]},
#    'id': 'hv72154416'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.47,
#     'place': '6 km ESE of Ridgely, Tennessee',
#     'time': 1601162111910,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60329796',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60329796&format=geojson',
#     'felt': 2,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 94,
#     'net': 'nm',
#     'code': '60329796',
#     'ids': ',nm60329796,us6000c1s7,',
#     'sources': ',nm,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 35,
#     'dmin': 0.01411,
#     'rms': 0.08,
#     'gap': 62,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 6 km ESE of Ridgely, Tennessee'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-89.4176667, 36.2441667, 7.14]},
#    'id': 'nm60329796'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.08,
#     'place': '4km SSW of Redlands, CA',
#     'time': 1601161953970,
#     'updated': 1601418597522,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704890',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704890&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '38704890',
#     'ids': ',ci38704890,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 41,
#     'dmin': 0.07443,
#     'rms': 0.17,
#     'gap': 79,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 4km SSW of Redlands, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.1965, 34.0193333, 14.28]},
#    'id': 'ci38704890'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.71,
#     'place': '89 km NW of Karluk, Alaska',
#     'time': 1601161812400,
#     'updated': 1601332883540,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91007653',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av91007653&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91007653',
#     'ids': ',av91007653,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': None,
#     'rms': 0.08,
#     'gap': 271,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.7 - 89 km NW of Karluk, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.4665, 58.1696666666667, 1.9]},
#    'id': 'av91007653'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '13 km ENE of Fox, Alaska',
#     'time': 1601161797335,
#     'updated': 1602044220176,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewuq69',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewuq69&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ak',
#     'code': '020cewuq69',
#     'ids': ',ak020cewuq69,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.21,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'explosion',
#     'title': 'M 1.0 Explosion - 13 km ENE of Fox, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.3327, 64.9845, 0]},
#    'id': 'ak020cewuq69'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '29 km SSE of Karyes, Greece',
#     'time': 1601161763175,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1s6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1s6&format=geojson',
#     'felt': 2,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 285,
#     'net': 'us',
#     'code': '6000c1s6',
#     'ids': ',us6000c1s6,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.546,
#     'rms': 0.59,
#     'gap': 53,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 29 km SSE of Karyes, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.3727, 40.012, 10]},
#    'id': 'us6000c1s6'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.01,
#     'place': '6km E of Mammoth Lakes, CA',
#     'time': 1601161689970,
#     'updated': 1601329684014,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463191',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463191&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'nc',
#     'code': '73463191',
#     'ids': ',nc73463191,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.01339,
#     'rms': 0.04,
#     'gap': 85,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.0 - 6km E of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9165, 37.634, 4.29]},
#    'id': 'nc73463191'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '49 km NNW of Petersville, Alaska',
#     'time': 1601161554124,
#     'updated': 1602044219913,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewtvbj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewtvbj&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '020cewtvbj',
#     'ids': ',ak020cewtvbj,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.3,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 49 km NNW of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.1438, 62.9058, 104.9]},
#    'id': 'ak020cewtvbj'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.99000001,
#     'place': '2 km SSE of P?hala, Hawaii',
#     'time': 1601161532000,
#     'updated': 1601161723460,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72154406',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv72154406&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 61,
#     'net': 'hv',
#     'code': '72154406',
#     'ids': ',hv72154406,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 87,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 2 km SSE of P?hala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.473663330078, 19.1844997406006, 31.4899997711182]},
#    'id': 'hv72154406'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.85,
#     'place': '14km NW of Parkfield, CA',
#     'time': 1601161495170,
#     'updated': 1601683028937,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463186',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463186&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'nc',
#     'code': '73463186',
#     'ids': ',nc73463186,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 31,
#     'dmin': 0.02474,
#     'rms': 0.06,
#     'gap': 115,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 14km NW of Parkfield, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-120.547, 35.9816667, 3.32]},
#    'id': 'nc73463186'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '16 km SSW of Eureka Roadhouse, Alaska',
#     'time': 1601161448181,
#     'updated': 1602044219626,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewtjp9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewtjp9&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '020cewtjp9',
#     'ids': ',ak020cewtjp9,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.77,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 16 km SSW of Eureka Roadhouse, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.2612, 61.8013, 36.3]},
#    'id': 'ak020cewtjp9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '63 km SSW of Shungnak, Alaska',
#     'time': 1601161160753,
#     'updated': 1602044219338,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewjxhi',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewjxhi&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '020cewjxhi',
#     'ids': ',ak020cewjxhi,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.57,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 63 km SSW of Shungnak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-157.595, 66.3446, 0.1]},
#    'id': 'ak020cewjxhi'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '227 km SSE of Ust’-Kamchatsk Staryy, Russia',
#     'time': 1601161121252,
#     'updated': 1607202189040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c3w7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c3w7&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000c3w7',
#     'ids': ',us6000c3w7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.534,
#     'rms': 0.73,
#     'gap': 179,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 227 km SSE of Ust’-Kamchatsk Staryy, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [164.1174, 54.4138, 10]},
#    'id': 'us6000c3w7'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '2 km WSW of Healy, Alaska',
#     'time': 1601161079367,
#     'updated': 1602044145256,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewjl26',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewjl26&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '020cewjl26',
#     'ids': ',ak020cewjl26,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 2 km WSW of Healy, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.0147, 63.8449, 117.6]},
#    'id': 'ak020cewjl26'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.4,
#     'place': '31 km SSE of Karyes, Greece',
#     'time': 1601160625082,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1rq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1rq&format=geojson',
#     'felt': 76,
#     'cdi': 7,
#     'mmi': 4.399,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 502,
#     'net': 'us',
#     'code': '6000c1rq',
#     'ids': ',us6000c1rq,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.585,
#     'rms': 0.58,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.4 - 31 km SSE of Karyes, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [24.3349, 39.9847, 10.38]},
#    'id': 'us6000c1rq'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '42 km NE of Livengood, Alaska',
#     'time': 1601160569974,
#     'updated': 1602044144990,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewht08',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewht08&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ak',
#     'code': '020cewht08',
#     'ids': ',ak020cewht08,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.8,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 42 km NE of Livengood, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.8033, 65.7442, 5]},
#    'id': 'ak020cewht08'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.72,
#     'place': '6 km N of Entiat, Washington',
#     'time': 1601160256990,
#     'updated': 1601697078410,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61677472',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61677472&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'uw',
#     'code': '61677472',
#     'ids': ',uw61677472,',
#     'sources': ',uw,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.1259,
#     'rms': 0.05,
#     'gap': 139,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 6 km N of Entiat, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.198666666667, 47.7355, 1.02]},
#    'id': 'uw61677472'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.49,
#     'place': '9km WSW of The Geysers, CA',
#     'time': 1601160028100,
#     'updated': 1601681525756,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463181',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463181&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 34,
#     'net': 'nc',
#     'code': '73463181',
#     'ids': ',nc73463181,',
#     'sources': ',nc,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 50,
#     'dmin': 0.01222,
#     'rms': 0.06,
#     'gap': 130,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 9km WSW of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.855, 38.7585, 4.73]},
#    'id': 'nc73463181'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.01,
#     'place': '12km WNW of Petrolia, CA',
#     'time': 1601159678670,
#     'updated': 1601536209030,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463176',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463176&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'nc',
#     'code': '73463176',
#     'ids': ',nc73463176,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.09911,
#     'rms': 0.09,
#     'gap': 245,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 12km WNW of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.4215, 40.3671667, 25.12]},
#    'id': 'nc73463176'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '26 km WSW of Petersville, Alaska',
#     'time': 1601159086995,
#     'updated': 1602044144717,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cewchdm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cewchdm&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '020cewchdm',
#     'ids': ',ak020cewchdm,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.33,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 26 km WSW of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2122, 62.3718, 82.8]},
#    'id': 'ak020cewchdm'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.52,
#     'place': '8km NNW of Rancho Cucamonga, CA',
#     'time': 1601158761510,
#     'updated': 1614580844822,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704866',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704866&format=geojson',
#     'felt': 27,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 107,
#     'net': 'ci',
#     'code': '38704866',
#     'ids': ',ci38704866,us6000c1rl,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 121,
#     'dmin': 0.06654,
#     'rms': 0.22,
#     'gap': 15,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 8km NNW of Rancho Cucamonga, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.607, 34.1876667, 6.87]},
#    'id': 'ci38704866'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.25,
#     'place': '4km W of Cobb, CA',
#     'time': 1601158533140,
#     'updated': 1601668763393,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463166',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463166&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nc',
#     'code': '73463166',
#     'ids': ',nc73463166,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 12,
#     'dmin': 0.01086,
#     'rms': 0.02,
#     'gap': 150,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 4km W of Cobb, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.7661667, 38.82, 1.67]},
#    'id': 'nc73463166'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '16 km W of Petersville, Alaska',
#     'time': 1601158235691,
#     'updated': 1602268803774,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cew9gik',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cew9gik&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '020cew9gik',
#     'ids': ',ak020cew9gik,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 16 km W of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.0714, 62.4721, 80.4]},
#    'id': 'ak020cew9gik'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '3km NNW of Loma Linda, CA',
#     'time': 1601157872390,
#     'updated': 1601351607234,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704858',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704858&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ci',
#     'code': '38704858',
#     'ids': ',ci38704858,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.03025,
#     'rms': 0.14,
#     'gap': 66,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 3km NNW of Loma Linda, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.2756667, 34.0756667, 14.04]},
#    'id': 'ci38704858'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.33,
#     'place': '7km WNW of The Geysers, CA',
#     'time': 1601157483150,
#     'updated': 1601679964605,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463156',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463156&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 27,
#     'net': 'nc',
#     'code': '73463156',
#     'ids': ',nc73463156,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 43,
#     'dmin': 0.003235,
#     'rms': 0.05,
#     'gap': 53,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 7km WNW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8253333, 38.8076667, 1.32]},
#    'id': 'nc73463156'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.51,
#     'place': '4km E of Mammoth Lakes, CA',
#     'time': 1601157420540,
#     'updated': 1601163186115,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463161',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463161&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'nc',
#     'code': '73463161',
#     'ids': ',nc73463161,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.02286,
#     'rms': 0.03,
#     'gap': 68,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 4km E of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.9278333, 37.6401667, 5.19]},
#    'id': 'nc73463161'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '6 km ESE of Ridgely, Tennessee',
#     'time': 1601157275340,
#     'updated': 1601989364470,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60329761',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nm60329761&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'nm',
#     'code': '60329761',
#     'ids': ',nm60329761,',
#     'sources': ',nm,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.0136,
#     'rms': 0.07,
#     'gap': 62,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 6 km ESE of Ridgely, Tennessee'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-89.4178333, 36.2436667, 6.92]},
#    'id': 'nm60329761'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.3,
#     'place': '3km ESE of The Geysers, CA',
#     'time': 1601156999410,
#     'updated': 1601536720281,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463151',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463151&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nc',
#     'code': '73463151',
#     'ids': ',nc73463151,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.003007,
#     'rms': 0.03,
#     'gap': 134,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 3km ESE of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.728, 38.7633333, 2.1]},
#    'id': 'nc73463151'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.22,
#     'place': '23km N of Trona, CA',
#     'time': 1601156129410,
#     'updated': 1601328558060,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37301116',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37301116&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'ci',
#     'code': '37301116',
#     'ids': ',ci37301116,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.09161,
#     'rms': 0.05,
#     'gap': 192,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.2 - 23km N of Trona, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.3483333, 35.966, 6.04]},
#    'id': 'ci37301116'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.6,
#     'place': '23km ESE of Little Lake, CA',
#     'time': 1601156117330,
#     'updated': 1601328163501,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704850',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704850&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '38704850',
#     'ids': ',ci38704850,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.06845,
#     'rms': 0.08,
#     'gap': 88,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 23km ESE of Little Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6678333, 35.8535, 10.97]},
#    'id': 'ci38704850'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.98,
#     'place': '7 km ESE of La Parguera, Puerto Rico',
#     'time': 1601155899760,
#     'updated': 1601159381824,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020270024',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020270024&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 137,
#     'net': 'pr',
#     'code': '2020270024',
#     'ids': ',pr2020270024,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.0631,
#     'rms': 0.1,
#     'gap': 200,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 7 km ESE of La Parguera, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.9828, 17.9548, 6]},
#    'id': 'pr2020270024'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '22 km ESE of Wright, Wyoming',
#     'time': 1601155261230,
#     'updated': 1607202174040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qs',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qs&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'us',
#     'code': '6000c1qs',
#     'ids': ',us6000c1qs,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.984,
#     'rms': 0.41,
#     'gap': 76,
#     'magType': 'ml',
#     'type': 'mining explosion',
#     'title': 'M 3.3 Mining Explosion - 22 km ESE of Wright, Wyoming'},
#    'geometry': {'type': 'Point', 'coordinates': [-105.2393, 43.6609, 0]},
#    'id': 'us6000c1qs'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.57,
#     'place': '9km WNW of Cobb, CA',
#     'time': 1601155215320,
#     'updated': 1601161263592,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73463146',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73463146&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'nc',
#     'code': '73463146',
#     'ids': ',nc73463146,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.01055,
#     'rms': 0.02,
#     'gap': 104,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 9km WNW of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8225021, 38.8414993, 1.53]},
#    'id': 'nc73463146'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.02,
#     'place': '6 km WSW of La Parguera, Puerto Rico',
#     'time': 1601154837810,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020270023',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2020270023&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
# ...
#     'place': '10 km SE of Katie, Oklahoma',
#     'time': 1600967740259,
#     'updated': 1601046447963,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2020svdm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2020svdm&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ok',
#     'code': '2020svdm',
#     'ids': ',ok2020svdm,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.07648499104,
#     'rms': 0.33,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.9 Quarry Blast - 10 km SE of Katie, Oklahoma'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.28266667, 34.51016667, 0]},
#    'id': 'ok2020svdm'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '51 km W of Mentone, Texas',
#     'time': 1600967413248,
#     'updated': 1607202176040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ne',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ne&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': '6000c0ne',
#     'ids': ',us6000c0ne,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.101,
#     'rms': 0.39,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 51 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.1421, 31.6978, 6.94]},
#    'id': 'us6000c0ne'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '49 km SSE of Denali National Park, Alaska',
#     'time': 1600967354182,
#     'updated': 1601928193213,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbi7c5h',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbi7c5h&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ak',
#     'code': '020cbi7c5h',
#     'ids': ',ak020cbi7c5h,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.5,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 49 km SSE of Denali National Park, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.4108, 63.1176, 1.8]},
#    'id': 'ak020cbi7c5h'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '12 km NNW of King Cove, Alaska',
#     'time': 1600967272138,
#     'updated': 1601928192973,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbi6zkv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbi6zkv&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'ak',
#     'code': '020cbi6zkv',
#     'ids': ',av91127651,ak020cbi6zkv,',
#     'sources': ',av,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.61,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 12 km NNW of King Cove, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-162.3737, 55.1724, 6.5]},
#    'id': 'ak020cbi6zkv'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.6,
#     'place': '30 km SE of Mina, Nevada',
#     'time': 1600967232280,
#     'updated': 1600967741038,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775434',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775434&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'nn',
#     'code': '00775434',
#     'ids': ',nn00775434,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.026,
#     'rms': 0.06,
#     'gap': 109.26,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 30 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.899, 38.167, 9.4]},
#    'id': 'nn00775434'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '34 km SE of Mina, Nevada',
#     'time': 1600967086400,
#     'updated': 1600967341872,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775433',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775433&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00775433',
#     'ids': ',nn00775433,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.02,
#     'rms': 0.05,
#     'gap': 90.16,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 34 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8878, 38.1305, 4.5]},
#    'id': 'nn00775433'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '111 km WNW of Arctic Village, Alaska',
#     'time': 1600966904248,
#     'updated': 1601928192718,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbi5oxq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbi5oxq&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '020cbi5oxq',
#     'ids': ',ak020cbi5oxq,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.39,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 111 km WNW of Arctic Village, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.9728, 68.5576, 3.3]},
#    'id': 'ak020cbi5oxq'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '62 km SSE of Sand Point, Alaska',
#     'time': 1600966864550,
#     'updated': 1607202193040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c5ut',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c5ut&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'us',
#     'code': '6000c5ut',
#     'ids': ',ak020cbi5lpw,us6000c5ut,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.247,
#     'rms': 0.4,
#     'gap': 190,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 62 km SSE of Sand Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-160.0165, 54.8486, 27.05]},
#    'id': 'us6000c5ut'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '43 km NW of Tatitlek, Alaska',
#     'time': 1600966785460,
#     'updated': 1601928192230,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbhwoqp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbhwoqp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '020cbhwoqp',
#     'ids': ',ak020cbhwoqp,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.75,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 43 km NW of Tatitlek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.277, 61.1307, 15]},
#    'id': 'ak020cbhwoqp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '15 km SSW of Cold Bay, Alaska',
#     'time': 1600966625104,
#     'updated': 1601928191987,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbhw74w',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbhw74w&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'ak',
#     'code': '020cbhw74w',
#     'ids': ',ak020cbhw74w,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.37,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 15 km SSW of Cold Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-162.7765, 55.0499, 131.2]},
#    'id': 'ak020cbhw74w'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '213 km W of Adak, Alaska',
#     'time': 1600966379125,
#     'updated': 1601928195311,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbhv7tk',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbhv7tk&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '020cbhv7tk',
#     'ids': ',ak020cbhv7tk,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.55,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 213 km W of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-179.7293, 51.8336, 143.9]},
#    'id': 'ak020cbhv7tk'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.48,
#     'place': '6 km W of Townsend, Montana',
#     'time': 1600966287300,
#     'updated': 1600986385530,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80465219',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=mb80465219&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 34,
#     'net': 'mb',
#     'code': '80465219',
#     'ids': ',mb80465219,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.329,
#     'rms': 0.14,
#     'gap': 169,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.5 Quarry Blast - 6 km W of Townsend, Montana'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.6056667, 46.329, -2]},
#    'id': 'mb80465219'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '11 km N of King Cove, Alaska',
#     'time': 1600965575856,
#     'updated': 1601928191743,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cbhsdrp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak020cbhsdrp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '020cbhsdrp',
#     'ids': ',av91007153,ak020cbhsdrp,',
#     'sources': ',av,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.45,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 11 km N of King Cove, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-162.2911, 55.1637, 7.9]},
#    'id': 'ak020cbhsdrp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '48 km ENE of Adak, Alaska',
#     'time': 1600965569518,
#     'updated': 1607202193040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c5uw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c5uw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '6000c5uw',
#     'ids': ',ak020cbhsda3,us6000c5uw,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.016,
#     'rms': 0.4,
#     'gap': 171,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 48 km ENE of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.9467, 51.9741, 162.4]},
#    'id': 'us6000c5uw'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '138 km SW of Hihifo, Tonga',
#     'time': 1600965503108,
#     'updated': 1607202188040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c36d',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c36d&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000c36d',
#     'ids': ',us6000c36d,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 4.055,
#     'rms': 0.83,
#     'gap': 64,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 138 km SW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-174.614, -16.9249, 212.67]},
#    'id': 'us6000c36d'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '27 km S of Mina, Nevada',
#     'time': 1600965282610,
#     'updated': 1600966921690,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00775431',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00775431&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00775431',
#     'ids': ',nn00775431,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.066,
#     'rms': 0.06,
#     'gap': 175.61,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 27 km S of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.1065, 38.143, 13.2]},
#    'id': 'nn00775431'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.32,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1600964832700,
#     'updated': 1600966743955,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73462406',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73462406&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nc',
#     'code': '73462406',
#     'ids': ',nc73462406,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.008129,
#     'rms': 0.02,
#     'gap': 69,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8216629, 38.8144989, 2.78]},
#    'id': 'nc73462406'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.64,
#     'place': '14km SSW of Searles Valley, CA',
#     'time': 1600964662310,
#     'updated': 1601075631081,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702778',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702778&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '38702778',
#     'ids': ',ci38702778,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 20,
#     'dmin': 0.06944,
#     'rms': 0.15,
#     'gap': 108,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 14km SSW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4793333, 35.6546667, 9.08]},
#    'id': 'ci38702778'},
#   ...],
#  'bbox': [-179.9633, -82.8837, -3.48, 179.9679, 79.7223, 606.89]}

# %% [markdown]
# Alle Erbeben mit den ungefähren Koordinaten von Mexiko. [Hier könnte man die ungefähr nachschlagen.](http://www.latlong.net/)

# %%
urlloc = '&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
url1+urlzeit+urlloc
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-09-01&endtime=2020-09-27&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
response = requests.get(url1+urlzeit+urlloc)
response.text
# Out:
# '{"type":"FeatureCollection","metadata":{"generated":1631521658000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-09-01&endtime=2020-09-27&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85","title":"USGS Earthquakes","status":200,"api":"1.12.2","count":172},"features":[{"type":"Feature","properties":{"mag":2.4,"place":"17 km SE of Ackerly, Texas","time":1601152788020,"updated":1607202180040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson","felt":3,"cdi":3.1,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":90,"net":"us","code":"6000c1qf","ids":",us6000c1qf,","sources":",us,","types":",dyfi,origin,phase-data,","nst":null,"dmin":0.315,"rms":0.36,"gap":28,"magType":"mb_lg","type":"earthquake","title":"M 2.4 - 17 km SE of Ackerly, Texas"},"geometry":{"type":"Point","coordinates":[-101.5925,32.4053,1.21]},"id":"us6000c1qf"},\n{"type":"Feature","properties":{"mag":2.99,"place":"87km ESE of Maneadero, B.C., MX","time":1601147573490,"updated":1607202184040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38704794","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704794&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":138,"net":"ci","code":"38704794","ids":",ci38704794,us6000c27k,","sources":",ci,us,","types":",nearby-cities,origin,phase-data,scitech-link,","nst":15,"dmin":0.1589,"rms":0.2,"gap":156,"magType":"ml","type":"earthquake","title":"M 3.0 - 87km ESE of Maneadero, B.C., MX"},"geometry":{"type":"Point","coordinates":[-115.6751667,31.5206667,7.21]},"id":"ci38704794"},\n{"type":"Feature","properties":{"mag":2.07,"place":"15km SSE of Primo Tapia, B.C., MX","time":1601085758960,"updated":1601306460055,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38704210","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704210&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":66,"net":"ci","code":"38704210","ids":",ci38704210,","sources":",ci,","types":",nearby-cities,origin,phase-data,scitech-link,","nst":20,"dmin":0.2791,"rms":0.11,"gap":244,"magType":"ml","type":"earthquake","title":"M 2.1 - 15km SSE of Primo Tapia, B.C., MX"},"geometry":{"type":"Point","coordinates":[-116.8616667,32.0895,17.82]},"id":"ci38704210"},\n{"type":"Feature","properties":{"mag":3.1,"place":"56 km S of Whites City, New Mexico","time":1601050250095,"updated":1607202178040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18w","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18w&format=geojson","felt":1,"cdi":3.1,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":148,"net":"us","code":"6000c18w","ids":",us6000c18w,","sources":",us,","types":",dyfi,origin,phase-data,","nst":null,"dmin":0.113,"rms":0.37,"gap":60,"magType":"ml","type":"earthquake","title":"M 3.1 - 56 km S of Whites City, New Mexico"},"geometry":{"type":"Point","coordinates":[-104.3683,31.6652,5]},"id":"us6000c18w"},\n{"type":"Feature","properties":{"mag":2.9,"place":"56 km S of Whites City, New Mexico","time":1601050163468,"updated":1607202178040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18r","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18r&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":129,"net":"us","code":"6000c18r","ids":",us6000c18r,","sources":",us,","types":",origin,phase-data,","nst":null,"dmin":0.099,"rms":0.31,"gap":62,"magType":"ml","type":"earthquake","title":"M 2.9 - 56 km S of Whites City, New Mexico"},"geometry":{"type":"Point","coordinates":[-104.3847,31.6634,5]},"id":"us6000c18r"},\n{"type":"Feature","properties":{"mag":1.24,"place":"22km NW of O ...

# %% [markdown]
# Dieser Wulst lässt sich aber ziemlich schwer lesen. Deshalb müssen wir das zuerst umformatieren und dann verstehen, wie das ganze strukturiert ist.

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1631521658000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2020-09-01&endtime=2020-09-27&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.12.2',
#   'count': 172},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.4,
#     'place': '17 km SE of Ackerly, Texas',
#     'time': 1601152788020,
#     'updated': 1607202180040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson',
#     'felt': 3,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 90,
#     'net': 'us',
#     'code': '6000c1qf',
#     'ids': ',us6000c1qf,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.315,
#     'rms': 0.36,
#     'gap': 28,
#     'magType': 'mb_lg',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 17 km SE of Ackerly, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-101.5925, 32.4053, 1.21]},
#    'id': 'us6000c1qf'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.99,
#     'place': '87km ESE of Maneadero, B.C., MX',
#     'time': 1601147573490,
#     'updated': 1607202184040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704794',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704794&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'ci',
#     'code': '38704794',
#     'ids': ',ci38704794,us6000c27k,',
#     'sources': ',ci,us,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.1589,
#     'rms': 0.2,
#     'gap': 156,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 87km ESE of Maneadero, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.6751667, 31.5206667, 7.21]},
#    'id': 'ci38704794'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.07,
#     'place': '15km SSE of Primo Tapia, B.C., MX',
#     'time': 1601085758960,
#     'updated': 1601306460055,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704210',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704210&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 66,
#     'net': 'ci',
#     'code': '38704210',
#     'ids': ',ci38704210,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 20,
#     'dmin': 0.2791,
#     'rms': 0.11,
#     'gap': 244,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 15km SSE of Primo Tapia, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.8616667, 32.0895, 17.82]},
#    'id': 'ci38704210'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '56 km S of Whites City, New Mexico',
#     'time': 1601050250095,
#     'updated': 1607202178040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18w',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18w&format=geojson',
#     'felt': 1,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'us',
#     'code': '6000c18w',
#     'ids': ',us6000c18w,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.113,
#     'rms': 0.37,
#     'gap': 60,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 56 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.3683, 31.6652, 5]},
#    'id': 'us6000c18w'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '56 km S of Whites City, New Mexico',
#     'time': 1601050163468,
#     'updated': 1607202178040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18r',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18r&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '6000c18r',
#     'ids': ',us6000c18r,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.099,
#     'rms': 0.31,
#     'gap': 62,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 56 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.3847, 31.6634, 5]},
#    'id': 'us6000c18r'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.24,
#     'place': '22km NW of Ocotillo, CA',
#     'time': 1601050011650,
#     'updated': 1601079281245,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38703714',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38703714&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'ci',
#     'code': '38703714',
#     'ids': ',ci38703714,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 43,
#     'dmin': 0.09913,
#     'rms': 0.16,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 22km NW of Ocotillo, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.1841667, 32.8588333, 8.12]},
#    'id': 'ci38703714'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '57 km S of Whites City, New Mexico',
#     'time': 1601019963592,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c119',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c119&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '6000c119',
#     'ids': ',us6000c119,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.085,
#     'rms': 0.67,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 57 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.4013, 31.6611, 5]},
#    'id': 'us6000c119'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.4,
#     'place': '58 km S of Whites City, New Mexico',
#     'time': 1600989253822,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0x4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0x4&format=geojson',
#     'felt': 2,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 178,
#     'net': 'us',
#     'code': '6000c0x4',
#     'ids': ',us6000c0x4,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.103,
#     'rms': 0.31,
#     'gap': 62,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 58 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.3811, 31.6523, 5]},
#    'id': 'us6000c0x4'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '73 km ENE of Mulegé, Mexico',
#     'time': 1600988802138,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0xh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0xh&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000c0xh',
#     'ids': ',us6000c0xh,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.899,
#     'rms': 0.93,
#     'gap': 112,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 73 km ENE of Mulegé, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.2685, 27.0779, 10]},
#    'id': 'us6000c0xh'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': '64 km ENE of Mulegé, Mexico',
#     'time': 1600988490369,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ww',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ww&format=geojson',
#     'felt': 3,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 433,
#     'net': 'us',
#     'code': '6000c0ww',
#     'ids': ',us6000c0ww,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.76,
#     'rms': 0.66,
#     'gap': 125,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.3 - 64 km ENE of Mulegé, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.4068, 27.1573, 10]},
#    'id': 'us6000c0ww'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '54 km S of Whites City, New Mexico',
#     'time': 1600985999605,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0wa',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0wa&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 130,
#     'net': 'us',
#     'code': '6000c0wa',
#     'ids': ',us6000c0wa,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.097,
#     'rms': 0.82,
#     'gap': 52,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 54 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.3402, 31.6825, 5]},
#    'id': 'us6000c0wa'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '51 km W of Mentone, Texas',
#     'time': 1600967413248,
#     'updated': 1607202176040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ne',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ne&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': '6000c0ne',
#     'ids': ',us6000c0ne,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.101,
#     'rms': 0.39,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 51 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.1421, 31.6978, 6.94]},
#    'id': 'us6000c0ne'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '42 km S of El Coyul, Mexico',
#     'time': 1600937210931,
#     'updated': 1607202193040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c6bh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c6bh&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000c6bh',
#     'ids': ',us6000c6bh,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.366,
#     'rms': 0.76,
#     'gap': 134,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 42 km S of El Coyul, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.8188, 15.5296, 10]},
#    'id': 'us6000c6bh'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '35 km SSW of La Gloria, Mexico',
#     'time': 1600919721238,
#     'updated': 1607202176040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ec',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ec&format=geojson',
#     'felt': 3,
#     'cdi': 2.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 299,
#     'net': 'us',
#     'code': '6000c0ec',
#     'ids': ',us6000c0ec,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.393,
#     'rms': 0.71,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 35 km SSW of La Gloria, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-94.1964, 15.8366, 71.35]},
#    'id': 'us6000c0ec'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '26km ENE of Pine Valley, CA',
#     'time': 1600917159220,
#     'updated': 1601065779480,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702266',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702266&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '38702266',
#     'ids': ',ci38702266,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 41,
#     'dmin': 0.02519,
#     'rms': 0.17,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 26km ENE of Pine Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2813333, 32.9375, 7.43]},
#    'id': 'ci38702266'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.82,
#     'place': '84km ESE of Maneadero, B.C., MX',
#     'time': 1600901392300,
#     'updated': 1607202177040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702074',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702074&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 122,
#     'net': 'ci',
#     'code': '38702074',
#     'ids': ',ci38702074,us6000c0s9,',
#     'sources': ',ci,us,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1291,
#     'rms': 0.16,
#     'gap': 146,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 84km ESE of Maneadero, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.7166667, 31.5073333, 9.2]},
#    'id': 'ci38702074'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.79,
#     'place': '26km SSW of Ocotillo Wells, CA',
#     'time': 1600900066820,
#     'updated': 1601062580793,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455773',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455773&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ci',
#     'code': '37455773',
#     'ids': ',ci37455773,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.0319,
#     'rms': 0.14,
#     'gap': 79,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 26km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2718333, 32.9368333, 12.48]},
#    'id': 'ci37455773'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.98,
#     'place': '27km SSW of Ocotillo Wells, CA',
#     'time': 1600900041020,
#     'updated': 1601061718708,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702042',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702042&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ci',
#     'code': '38702042',
#     'ids': ',ci38702042,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 36,
#     'dmin': 0.03621,
#     'rms': 0.18,
#     'gap': 79,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 27km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.271, 32.9306667, 11.16]},
#    'id': 'ci38702042'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.68,
#     'place': '27km ENE of Pine Valley, CA',
#     'time': 1600897027960,
#     'updated': 1600964852599,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701954',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701954&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'ci',
#     'code': '38701954',
#     'ids': ',ci38701954,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.04567,
#     'rms': 0.14,
#     'gap': 99,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 27km ENE of Pine Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2633333, 32.9236667, 5.73]},
#    'id': 'ci38701954'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '68 km SSW of Acajutla, El Salvador',
#     'time': 1600893772732,
#     'updated': 1607202175040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c09c',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c09c&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000c09c',
#     'ids': ',us6000c09c,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.531,
#     'rms': 1.23,
#     'gap': 87,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 68 km SSW of Acajutla, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-90.081, 13.0288, 35]},
#    'id': 'us6000c09c'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.74,
#     'place': '27km SSW of Ocotillo Wells, CA',
#     'time': 1600886500280,
#     'updated': 1601056931490,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701586',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701586&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 47,
#     'net': 'ci',
#     'code': '38701586',
#     'ids': ',ci38701586,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 70,
#     'dmin': 0.04705,
#     'rms': 0.2,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 27km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2618333, 32.923, 5.58]},
#    'id': 'ci38701586'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.02,
#     'place': '27km ENE of Pine Valley, CA',
#     'time': 1600886324930,
#     'updated': 1600892960562,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701570',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701570&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 16,
#     'net': 'ci',
#     'code': '38701570',
#     'ids': ',ci38701570,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 17,
#     'dmin': 0.04919,
#     'rms': 0.13,
#     'gap': 129,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 27km ENE of Pine Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2641667, 32.918, 4.45]},
#    'id': 'ci38701570'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '17km E of Ocotillo, CA',
#     'time': 1600859889580,
#     'updated': 1600989545658,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38700914',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38700914&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ci',
#     'code': '38700914',
#     'ids': ',ci38700914,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 30,
#     'dmin': 0.06935,
#     'rms': 0.22,
#     'gap': 59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 17km E of Ocotillo, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.8123333, 32.7455, 10.15]},
#    'id': 'ci38700914'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '85 km SSW of Nueva Concepción, Guatemala',
#     'time': 1600854580070,
#     'updated': 1607202175040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c002',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c002&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000c002',
#     'ids': ',us6000c002,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.025,
#     'rms': 0.34,
#     'gap': 181,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 85 km SSW of Nueva Concepción, Guatemala'},
#    'geometry': {'type': 'Point', 'coordinates': [-91.6196, 13.496, 41.98]},
#    'id': 'us6000c002'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '15 km NW of Midland, Texas',
#     'time': 1600841079927,
#     'updated': 1607202175040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzyu',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzyu&format=geojson',
#     'felt': 5,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'us',
#     'code': '6000bzyu',
#     'ids': ',us6000bzyu,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.121,
#     'rms': 0.37,
#     'gap': 42,
#     'magType': 'mb_lg',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 15 km NW of Midland, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-102.1797, 32.1058, 5]},
#    'id': 'us6000bzyu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '34 km SSW of Ocós, Guatemala',
#     'time': 1600815391099,
#     'updated': 1606599125040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzvq',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzvq&format=geojson',
#     'felt': 6,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 357,
#     'net': 'us',
#     'code': '6000bzvq',
#     'ids': ',us6000bzvq,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.675,
#     'rms': 0.96,
#     'gap': 184,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 34 km SSW of Ocós, Guatemala'},
#    'geometry': {'type': 'Point', 'coordinates': [-92.323, 14.2293, 62.19]},
#    'id': 'us6000bzvq'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.98,
#     'place': '23km SW of Ocotillo Wells, CA',
#     'time': 1600797230570,
#     'updated': 1600970060960,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38699938',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38699938&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ci',
#     'code': '38699938',
#     'ids': ',ci38699938,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 27,
#     'dmin': 0.03087,
#     'rms': 0.17,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 23km SW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2946667, 32.9846667, 6.33]},
#    'id': 'ci38699938'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '53 km ENE of San Vicente, Mexico',
#     'time': 1600773651828,
#     'updated': 1606599124040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bznb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bznb&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '6000bznb',
#     'ids': ',ci38699506,us6000bznb,',
#     'sources': ',ci,us,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': None,
#     'dmin': 0.121,
#     'rms': 0.51,
#     'gap': 147,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 53 km ENE of San Vicente, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.717, 31.4988, 10]},
#    'id': 'us6000bznb'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.86,
#     'place': '22km WNW of Ocotillo, CA',
#     'time': 1600767813990,
#     'updated': 1600782397124,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38699426',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38699426&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'ci',
#     'code': '38699426',
#     'ids': ',ci38699426,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.09419,
#     'rms': 0.2,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 22km WNW of Ocotillo, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2028333, 32.8228333, 9.24]},
#    'id': 'ci38699426'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '49 km NW of Toyah, Texas',
#     'time': 1600757420918,
#     'updated': 1606599123040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzkm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzkm&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'us',
#     'code': '6000bzkm',
#     'ids': ',us6000bzkm,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.261,
#     'rms': 0.38,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 49 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.2137, 31.5764, 5]},
#    'id': 'us6000bzkm'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.41,
#     'place': '5km NE of Rancho San Diego, CA',
#     'time': 1600714818780,
#     'updated': 1600798559126,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38698434',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38698434&format=geojson',
#     'felt': 2,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 31,
#     'net': 'ci',
#     'code': '38698434',
#     'ids': ',ci38698434,',
#     'sources': ',ci,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.05896,
#     'rms': 0.26,
#     'gap': 90,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.4 Quarry Blast - 5km NE of Rancho San Diego, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.8915, 32.7761667, -0.36]},
#    'id': 'ci38698434'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.34,
#     'place': '8km NNW of Ocotillo, CA',
#     'time': 1600703760040,
#     'updated': 1600727090156,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38697994',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38697994&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'ci',
#     'code': '38697994',
#     'ids': ',ci38697994,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 2,
#     'dmin': 0.1704,
#     'rms': 0.03,
#     'gap': 304,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 8km NNW of Ocotillo, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.0123333, 32.8005, 5.46]},
#    'id': 'ci38697994'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.67,
#     'place': '25km SSW of Ocotillo Wells, CA',
#     'time': 1600686504020,
#     'updated': 1614378518569,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38697586',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38697586&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'ci',
#     'code': '38697586',
#     'ids': ',ci38697586,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.05445,
#     'rms': 0.15,
#     'gap': 102,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 25km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2406667, 32.941, 6.29]},
#    'id': 'ci38697586'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'Revilla Gigedo Islands region',
#     'time': 1600678801567,
#     'updated': 1606599120040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqpl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqpl&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000bqpl',
#     'ids': ',us7000bqpl,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.697,
#     'rms': 1.25,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - Revilla Gigedo Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-109.4142, 19.6802, 10]},
#    'id': 'us7000bqpl'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '97 km SW of Altata, Mexico',
#     'time': 1600662953049,
#     'updated': 1606599119040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqnk',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqnk&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000bqnk',
#     'ids': ',us7000bqnk,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.944,
#     'rms': 0.91,
#     'gap': 165,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 97 km SW of Altata, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-108.5768, 23.9865, 10]},
#    'id': 'us7000bqnk'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': 'Revilla Gigedo Islands region',
#     'time': 1600662130893,
#     'updated': 1606599119040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqnj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqnj&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000bqnj',
#     'ids': ',us7000bqnj,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.671,
#     'rms': 0.93,
#     'gap': 89,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - Revilla Gigedo Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-109.4273, 19.6478, 10]},
#    'id': 'us7000bqnj'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.52,
#     'place': '17km WNW of Progreso, B.C., MX',
#     'time': 1600634609280,
#     'updated': 1600967448649,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696962',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696962&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 36,
#     'net': 'ci',
#     'code': '38696962',
#     'ids': ',ci38696962,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 24,
#     'dmin': 0.03105,
#     'rms': 0.22,
#     'gap': 129,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 17km WNW of Progreso, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.7578333, 32.6331667, 10.18]},
#    'id': 'ci38696962'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '57 km ENE of San Vicente, Mexico',
#     'time': 1600623062389,
#     'updated': 1606599118040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqiw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqiw&format=geojson',
#     'felt': 2,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 200,
#     'net': 'us',
#     'code': '7000bqiw',
#     'ids': ',ci38696834,us7000bqiw,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': None,
#     'dmin': 0.136,
#     'rms': 1.07,
#     'gap': 103,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 57 km ENE of San Vicente, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.6756, 31.4921, 10]},
#    'id': 'us7000bqiw'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.51,
#     'place': '0km NE of El Centro, CA',
#     'time': 1600615709220,
#     'updated': 1600887179288,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696746',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696746&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ci',
#     'code': '38696746',
#     'ids': ',ci38696746,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 21,
#     'dmin': 0.05213,
#     'rms': 0.21,
#     'gap': 86,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 0km NE of El Centro, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.5543333, 32.791, 10.48]},
#    'id': 'ci38696746'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.39,
#     'place': '1km E of El Centro, CA',
#     'time': 1600610366930,
#     'updated': 1600885431930,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696722',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696722&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ci',
#     'code': '38696722',
#     'ids': ',ci38696722,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.05269,
#     'rms': 0.2,
#     'gap': 126,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 1km E of El Centro, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5495, 32.7878333, 10.23]},
#    'id': 'ci38696722'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.23,
#     'place': '2km ESE of El Centro, CA',
#     'time': 1600610226040,
#     'updated': 1600885102071,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696714',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696714&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'ci',
#     'code': '38696714',
#     'ids': ',ci38696714,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.05242,
#     'rms': 0.19,
#     'gap': 88,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 2km ESE of El Centro, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5441667, 32.7818333, 10.77]},
#    'id': 'ci38696714'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.76,
#     'place': '32km WSW of Encinitas, CA',
#     'time': 1600608522520,
#     'updated': 1600883481909,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696690',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696690&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 48,
#     'net': 'ci',
#     'code': '38696690',
#     'ids': ',ci38696690,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 36,
#     'dmin': 0.3253,
#     'rms': 0.13,
#     'gap': 186,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 32km WSW of Encinitas, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6115, 32.9376667, 15.29]},
#    'id': 'ci38696690'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.11,
#     'place': '26km SSW of Ocotillo Wells, CA',
#     'time': 1600602644410,
#     'updated': 1600883077866,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696642',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696642&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '38696642',
#     'ids': ',ci38696642,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 48,
#     'dmin': 0.02346,
#     'rms': 0.19,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 26km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2803333, 32.9413333, 8.32]},
#    'id': 'ci38696642'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.34,
#     'place': '1km SE of El Centro, CA',
#     'time': 1600599848950,
#     'updated': 1600808497246,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696594',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696594&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ci',
#     'code': '38696594',
#     'ids': ',ci38696594,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.04699,
#     'rms': 0.24,
#     'gap': 93,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 1km SE of El Centro, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5541667, 32.7836667, 8.45]},
#    'id': 'ci38696594'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.49,
#     'place': '1km NNE of El Centro, CA',
#     'time': 1600596371340,
#     'updated': 1600801363849,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455637',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455637&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 34,
#     'net': 'ci',
#     'code': '37455637',
#     'ids': ',ci37455637,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.05693,
#     'rms': 0.26,
#     'gap': 108,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 1km NNE of El Centro, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.5525, 32.796, 7.34]},
#    'id': 'ci37455637'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.59,
#     'place': '1km ESE of El Centro, CA',
#     'time': 1600596365900,
#     'updated': 1600800975438,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696562',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696562&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ci',
#     'code': '38696562',
#     'ids': ',ci38696562,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 27,
#     'dmin': 0.05027,
#     'rms': 0.24,
#     'gap': 93,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 1km ESE of El Centro, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5501667, 32.7848333, 9.68]},
#    'id': 'ci38696562'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.79,
#     'place': '26km SSW of Ocotillo Wells, CA',
#     'time': 1600586780220,
#     'updated': 1600797393855,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696514',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696514&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ci',
#     'code': '38696514',
#     'ids': ',ci38696514,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 37,
#     'dmin': 0.02101,
#     'rms': 0.19,
#     'gap': 97,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 26km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2835, 32.9418333, 7.85]},
#    'id': 'ci38696514'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.21,
#     'place': '26km SSW of Ocotillo Wells, CA',
#     'time': 1600586772180,
#     'updated': 1600798235333,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455621',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455621&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'ci',
#     'code': '37455621',
#     'ids': ',ci37455621,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.02384,
#     'rms': 0.15,
#     'gap': 153,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.2 - 26km SSW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.2791667, 32.9421667, 8.51]},
#    'id': 'ci37455621'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.67,
#     'place': '18km WNW of Progreso, B.C., MX',
#     'time': 1600580546630,
#     'updated': 1600794310270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696450',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696450&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '38696450',
#     'ids': ',ci38696450,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.03304,
#     'rms': 0.21,
#     'gap': 129,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 18km WNW of Progreso, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.761, 32.6338333, 9.45]},
#    'id': 'ci38696450'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.08,
#     'place': '11km W of Delta, B.C., MX',
#     'time': 1600574366970,
#     'updated': 1600720311600,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696410',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696410&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 67,
#     'net': 'ci',
#     'code': '38696410',
#     'ids': ',ci38696410,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.0827,
#     'rms': 0.26,
#     'gap': 132,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 11km W of Delta, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.3098333, 32.3366667, 10.66]},
#    'id': 'ci38696410'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.39,
#     'place': '88km ESE of Maneadero, B.C., MX',
#     'time': 1600571119170,
#     'updated': 1600791502200,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696378',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696378&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 88,
#     'net': 'ci',
#     'code': '38696378',
#     'ids': ',ci38696378,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 6,
#     'dmin': 0.1758,
#     'rms': 0.12,
#     'gap': 219,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 88km ESE of Maneadero, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.6603333, 31.5323333, -1.18]},
#    'id': 'ci38696378'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '11 km W of Santa Tecla, El Salvador',
#     'time': 1600554187478,
#     'updated': 1606599115040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqdw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqdw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'us',
#     'code': '7000bqdw',
#     'ids': ',us7000bqdw,',
#     'sources': ',us,',
#     'types': ',impact-text,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.706,
#     'rms': 0.1,
#     'gap': 192,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 11 km W of Santa Tecla, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3847, 13.6888, 10]},
#    'id': 'us7000bqdw'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '36 km SW of Puerto El Triunfo, El Salvador',
#     'time': 1600522325759,
#     'updated': 1606599114040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0i1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0i1&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000c0i1',
#     'ids': ',us6000c0i1,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.456,
#     'rms': 0.95,
#     'gap': 174,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 36 km SW of Puerto El Triunfo, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7889, 13.0447, 67.3]},
#    'id': 'us6000c0i1'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '11 km SW of Mazatán, Mexico',
#     'time': 1600495384162,
# ...
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh6x',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh6x&format=geojson',
#     'felt': 151,
#     'cdi': 5.2,
#     'mmi': 4.067,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 301,
#     'net': 'us',
#     'code': '7000bh6x',
#     'ids': ',us7000bh6x,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.182,
#     'rms': 0.8,
#     'gap': 78,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 1 km W of Pollard, Alabama'},
#    'geometry': {'type': 'Point', 'coordinates': [-87.1846, 31.0271, 4]},
#    'id': 'us7000bh6x'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.25,
#     'place': '23km NW of Ocotillo, CA',
#     'time': 1599141992190,
#     'updated': 1599164219837,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369711',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369711&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'ci',
#     'code': '39369711',
#     'ids': ',ci39369711,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 51,
#     'dmin': 0.1039,
#     'rms': 0.21,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 23km NW of Ocotillo, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.1851667, 32.8648333, 6.47]},
#    'id': 'ci39369711'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.06,
#     'place': '7km W of Progreso, B.C., MX',
#     'time': 1599140807770,
#     'updated': 1599162473010,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369687',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369687&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'ci',
#     'code': '39369687',
#     'ids': ',ci39369687,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.0946,
#     'rms': 0.26,
#     'gap': 131,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 7km W of Progreso, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.6611667, 32.5721667, 11.45]},
#    'id': 'ci39369687'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '147 km SW of Emiliano Zapata, Mexico',
#     'time': 1599137191635,
#     'updated': 1605642266040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh4q',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh4q&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000bh4q',
#     'ids': ',us7000bh4q,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.251,
#     'rms': 1.3,
#     'gap': 221,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 147 km SW of Emiliano Zapata, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-106.07, 18.56, 10]},
#    'id': 'us7000bh4q'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.55,
#     'place': '12km WSW of El Centro, CA',
#     'time': 1599131784500,
#     'updated': 1599164793558,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37299004',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37299004&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'ci',
#     'code': '37299004',
#     'ids': ',ci37299004,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 2,
#     'dmin': 0.1185,
#     'rms': 0.03,
#     'gap': 317,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 12km WSW of El Centro, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.686, 32.7631667, 2.87]},
#    'id': 'ci37299004'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '22km NW of Ocotillo, CA',
#     'time': 1599131077010,
#     'updated': 1599157285620,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369599',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369599&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'ci',
#     'code': '39369599',
#     'ids': ',ci39369599,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 27,
#     'dmin': 0.09883,
#     'rms': 0.16,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 22km NW of Ocotillo, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.1755, 32.8656667, 9.47]},
#    'id': 'ci39369599'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.79,
#     'place': '88km ESE of Maneadero, B.C., MX',
#     'time': 1599128258000,
#     'updated': 1605642266040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369543',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369543&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 120,
#     'net': 'ci',
#     'code': '39369543',
#     'ids': ',ci39369543,us7000bh3w,',
#     'sources': ',ci,us,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1746,
#     'rms': 0.11,
#     'gap': 96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 88km ESE of Maneadero, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.662, 31.5318333, 11.06]},
#    'id': 'ci39369543'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.64,
#     'place': '23km NW of Ocotillo, CA',
#     'time': 1599127849470,
#     'updated': 1599159360120,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369535',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369535&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 41,
#     'net': 'ci',
#     'code': '39369535',
#     'ids': ',ci39369535,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 61,
#     'dmin': 0.1004,
#     'rms': 0.19,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 23km NW of Ocotillo, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.1821667, 32.8625, 6.77]},
#    'id': 'ci39369535'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '48 km W of Mentone, Texas',
#     'time': 1599105147111,
#     'updated': 1605642265040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh0h',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh0h&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'us',
#     'code': '7000bh0h',
#     'ids': ',us7000bh0h,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.064,
#     'rms': 0.35,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 48 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.1057, 31.736, 8.03]},
#    'id': 'us7000bh0h'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.4,
#     'place': '20 km E of La Paz, Mexico',
#     'time': 1599101122910,
#     'updated': 1605642264040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh03',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh03&format=geojson',
#     'felt': 6,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 180,
#     'net': 'us',
#     'code': '7000bh03',
#     'ids': ',us7000bh03,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.511,
#     'rms': 0.72,
#     'gap': 162,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 20 km E of La Paz, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.0976, 24.1798, 10]},
#    'id': 'us7000bh03'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '47 km W of Mentone, Texas',
#     'time': 1599055998582,
#     'updated': 1605642262040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgj8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgj8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'us',
#     'code': '7000bgj8',
#     'ids': ',us7000bgj8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.062,
#     'rms': 0.29,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 47 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.1039, 31.7377, 6.91]},
#    'id': 'us7000bgj8'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.59,
#     'place': '1km NW of El Centro, CA',
#     'time': 1599025263590,
#     'updated': 1599078829270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39368159',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39368159&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ci',
#     'code': '39368159',
#     'ids': ',ci39368159,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 26,
#     'dmin': 0.05138,
#     'rms': 0.23,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 1km NW of El Centro, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.565, 32.7965, 12.51]},
#    'id': 'ci39368159'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '47 km W of Mentone, Texas',
#     'time': 1599023915195,
#     'updated': 1605642261040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgbt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgbt&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '7000bgbt',
#     'ids': ',us7000bgbt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.058,
#     'rms': 0.38,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 47 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.0994, 31.7371, 5.27]},
#    'id': 'us7000bgbt'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '45 km W of Mentone, Texas',
#     'time': 1599022369510,
#     'updated': 1605642261040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgb9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgb9&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'us',
#     'code': '7000bgb9',
#     'ids': ',us7000bgb9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.044,
#     'rms': 0.68,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 45 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.072, 31.76, 5]},
#    'id': 'us7000bgb9'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '47 km W of Mentone, Texas',
#     'time': 1599022306611,
#     'updated': 1605642261040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgb8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgb8&format=geojson',
#     'felt': 2,
#     'cdi': 2.7,
#     'mmi': 4.134,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'us',
#     'code': '7000bgb8',
#     'ids': ',us7000bgb8,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.059,
#     'rms': 0.47,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 47 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.099, 31.7235, 8.58]},
#    'id': 'us7000bgb8'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.27,
#     'place': '16km E of Ocotillo, CA',
#     'time': 1599011478030,
#     'updated': 1599072735277,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39368095',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39368095&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 25,
#     'net': 'ci',
#     'code': '39368095',
#     'ids': ',ci39368095,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 21,
#     'dmin': 0.07347,
#     'rms': 0.18,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 16km E of Ocotillo, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.8186667, 32.755, 6.93]},
#    'id': 'ci39368095'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.28,
#     'place': '4km ENE of Rancho San Diego, CA',
#     'time': 1598986836650,
#     'updated': 1599078592353,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39367687',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39367687&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 25,
#     'net': 'ci',
#     'code': '39367687',
#     'ids': ',ci39367687,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.0479,
#     'rms': 0.13,
#     'gap': 88,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.3 Quarry Blast - 4km ENE of Rancho San Diego, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.897, 32.7645, 6.07]},
#    'id': 'ci39367687'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '58 km ENE of San Vicente, Mexico',
#     'time': 1598946094388,
#     'updated': 1604774923040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfn0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfn0&format=geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'us',
#     'code': '7000bfn0',
#     'ids': ',ci39367079,us7000bfn0,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': None,
#     'dmin': 0.132,
#     'rms': 1.17,
#     'gap': 122,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 58 km ENE of San Vicente, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.6461, 31.4528, 20.51]},
#    'id': 'us7000bfn0'}],
#  'bbox': [-117.7123333, 13.0288, -1.18, -87.1846, 32.998, 191.86]}

# %%
dct = response.json()

# %% [markdown]
# Um sicher zu gehen, prüfen wir nochmals den Datentyp.

# %%
type(dct)
# Out:
# dict

# %%
len(dct)
# Out:
# 4

# %% [markdown]
# Schauen wir uns alle keys und values an

# %%
for key in dct:
    print(key)
# Out:
# type
# metadata
# features
# bbox

# %% [markdown]
# Features interessiert uns.

# %%
dct['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 2.4,
#    'place': '17 km SE of Ackerly, Texas',
#    'time': 1601152788020,
#    'updated': 1607202180040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson',
#    'felt': 3,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 90,
#    'net': 'us',
#    'code': '6000c1qf',
#    'ids': ',us6000c1qf,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.315,
#    'rms': 0.36,
#    'gap': 28,
#    'magType': 'mb_lg',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 17 km SE of Ackerly, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.5925, 32.4053, 1.21]},
#   'id': 'us6000c1qf'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.99,
#    'place': '87km ESE of Maneadero, B.C., MX',
#    'time': 1601147573490,
#    'updated': 1607202184040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704794',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704794&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 138,
#    'net': 'ci',
#    'code': '38704794',
#    'ids': ',ci38704794,us6000c27k,',
#    'sources': ',ci,us,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 15,
#    'dmin': 0.1589,
#    'rms': 0.2,
#    'gap': 156,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.0 - 87km ESE of Maneadero, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.6751667, 31.5206667, 7.21]},
#   'id': 'ci38704794'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.07,
#    'place': '15km SSE of Primo Tapia, B.C., MX',
#    'time': 1601085758960,
#    'updated': 1601306460055,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38704210',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38704210&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 66,
#    'net': 'ci',
#    'code': '38704210',
#    'ids': ',ci38704210,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 20,
#    'dmin': 0.2791,
#    'rms': 0.11,
#    'gap': 244,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 15km SSE of Primo Tapia, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.8616667, 32.0895, 17.82]},
#   'id': 'ci38704210'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.1,
#    'place': '56 km S of Whites City, New Mexico',
#    'time': 1601050250095,
#    'updated': 1607202178040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18w',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18w&format=geojson',
#    'felt': 1,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 148,
#    'net': 'us',
#    'code': '6000c18w',
#    'ids': ',us6000c18w,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.113,
#    'rms': 0.37,
#    'gap': 60,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 56 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.3683, 31.6652, 5]},
#   'id': 'us6000c18w'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '56 km S of Whites City, New Mexico',
#    'time': 1601050163468,
#    'updated': 1607202178040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c18r',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c18r&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '6000c18r',
#    'ids': ',us6000c18r,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.099,
#    'rms': 0.31,
#    'gap': 62,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 56 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.3847, 31.6634, 5]},
#   'id': 'us6000c18r'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.24,
#    'place': '22km NW of Ocotillo, CA',
#    'time': 1601050011650,
#    'updated': 1601079281245,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38703714',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38703714&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'ci',
#    'code': '38703714',
#    'ids': ',ci38703714,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 43,
#    'dmin': 0.09913,
#    'rms': 0.16,
#    'gap': 69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 22km NW of Ocotillo, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.1841667, 32.8588333, 8.12]},
#   'id': 'ci38703714'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '57 km S of Whites City, New Mexico',
#    'time': 1601019963592,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c119',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c119&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '6000c119',
#    'ids': ',us6000c119,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.085,
#    'rms': 0.67,
#    'gap': 63,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 57 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.4013, 31.6611, 5]},
#   'id': 'us6000c119'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.4,
#    'place': '58 km S of Whites City, New Mexico',
#    'time': 1600989253822,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0x4',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0x4&format=geojson',
#    'felt': 2,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 178,
#    'net': 'us',
#    'code': '6000c0x4',
#    'ids': ',us6000c0x4,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.103,
#    'rms': 0.31,
#    'gap': 62,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.4 - 58 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.3811, 31.6523, 5]},
#   'id': 'us6000c0x4'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.6,
#    'place': '73 km ENE of Mulegé, Mexico',
#    'time': 1600988802138,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0xh',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0xh&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 326,
#    'net': 'us',
#    'code': '6000c0xh',
#    'ids': ',us6000c0xh,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.899,
#    'rms': 0.93,
#    'gap': 112,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.6 - 73 km ENE of Mulegé, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-111.2685, 27.0779, 10]},
#   'id': 'us6000c0xh'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.3,
#    'place': '64 km ENE of Mulegé, Mexico',
#    'time': 1600988490369,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ww',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ww&format=geojson',
#    'felt': 3,
#    'cdi': 3.8,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 433,
#    'net': 'us',
#    'code': '6000c0ww',
#    'ids': ',us6000c0ww,',
#    'sources': ',us,',
#    'types': ',dyfi,moment-tensor,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.76,
#    'rms': 0.66,
#    'gap': 125,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.3 - 64 km ENE of Mulegé, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-111.4068, 27.1573, 10]},
#   'id': 'us6000c0ww'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '54 km S of Whites City, New Mexico',
#    'time': 1600985999605,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0wa',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0wa&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 130,
#    'net': 'us',
#    'code': '6000c0wa',
#    'ids': ',us6000c0wa,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.097,
#    'rms': 0.82,
#    'gap': 52,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 54 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.3402, 31.6825, 5]},
#   'id': 'us6000c0wa'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.6,
#    'place': '51 km W of Mentone, Texas',
#    'time': 1600967413248,
#    'updated': 1607202176040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ne',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ne&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 104,
#    'net': 'us',
#    'code': '6000c0ne',
#    'ids': ',us6000c0ne,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.101,
#    'rms': 0.39,
#    'gap': 49,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 51 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.1421, 31.6978, 6.94]},
#   'id': 'us6000c0ne'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '42 km S of El Coyul, Mexico',
#    'time': 1600937210931,
#    'updated': 1607202193040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c6bh',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c6bh&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 271,
#    'net': 'us',
#    'code': '6000c6bh',
#    'ids': ',us6000c6bh,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.366,
#    'rms': 0.76,
#    'gap': 134,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 42 km S of El Coyul, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-95.8188, 15.5296, 10]},
#   'id': 'us6000c6bh'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '35 km SSW of La Gloria, Mexico',
#    'time': 1600919721238,
#    'updated': 1607202176040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0ec',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0ec&format=geojson',
#    'felt': 3,
#    'cdi': 2.6,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 299,
#    'net': 'us',
#    'code': '6000c0ec',
#    'ids': ',us6000c0ec,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 1.393,
#    'rms': 0.71,
#    'gap': 98,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 35 km SSW of La Gloria, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-94.1964, 15.8366, 71.35]},
#   'id': 'us6000c0ec'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.09,
#    'place': '26km ENE of Pine Valley, CA',
#    'time': 1600917159220,
#    'updated': 1601065779480,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702266',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702266&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'ci',
#    'code': '38702266',
#    'ids': ',ci38702266,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 41,
#    'dmin': 0.02519,
#    'rms': 0.17,
#    'gap': 58,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 26km ENE of Pine Valley, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2813333, 32.9375, 7.43]},
#   'id': 'ci38702266'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.82,
#    'place': '84km ESE of Maneadero, B.C., MX',
#    'time': 1600901392300,
#    'updated': 1607202177040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702074',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702074&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 122,
#    'net': 'ci',
#    'code': '38702074',
#    'ids': ',ci38702074,us6000c0s9,',
#    'sources': ',ci,us,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1291,
#    'rms': 0.16,
#    'gap': 146,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 84km ESE of Maneadero, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.7166667, 31.5073333, 9.2]},
#   'id': 'ci38702074'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.79,
#    'place': '26km SSW of Ocotillo Wells, CA',
#    'time': 1600900066820,
#    'updated': 1601062580793,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455773',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455773&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'ci',
#    'code': '37455773',
#    'ids': ',ci37455773,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.0319,
#    'rms': 0.14,
#    'gap': 79,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 26km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2718333, 32.9368333, 12.48]},
#   'id': 'ci37455773'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.98,
#    'place': '27km SSW of Ocotillo Wells, CA',
#    'time': 1600900041020,
#    'updated': 1601061718708,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38702042',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38702042&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'ci',
#    'code': '38702042',
#    'ids': ',ci38702042,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 36,
#    'dmin': 0.03621,
#    'rms': 0.18,
#    'gap': 79,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 27km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.271, 32.9306667, 11.16]},
#   'id': 'ci38702042'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.68,
#    'place': '27km ENE of Pine Valley, CA',
#    'time': 1600897027960,
#    'updated': 1600964852599,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701954',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701954&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'ci',
#    'code': '38701954',
#    'ids': ',ci38701954,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.04567,
#    'rms': 0.14,
#    'gap': 99,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 27km ENE of Pine Valley, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2633333, 32.9236667, 5.73]},
#   'id': 'ci38701954'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.6,
#    'place': '68 km SSW of Acajutla, El Salvador',
#    'time': 1600893772732,
#    'updated': 1607202175040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c09c',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c09c&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 326,
#    'net': 'us',
#    'code': '6000c09c',
#    'ids': ',us6000c09c,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 1.531,
#    'rms': 1.23,
#    'gap': 87,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.6 - 68 km SSW of Acajutla, El Salvador'},
#   'geometry': {'type': 'Point', 'coordinates': [-90.081, 13.0288, 35]},
#   'id': 'us6000c09c'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.74,
#    'place': '27km SSW of Ocotillo Wells, CA',
#    'time': 1600886500280,
#    'updated': 1601056931490,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701586',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701586&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 47,
#    'net': 'ci',
#    'code': '38701586',
#    'ids': ',ci38701586,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 70,
#    'dmin': 0.04705,
#    'rms': 0.2,
#    'gap': 56,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 27km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2618333, 32.923, 5.58]},
#   'id': 'ci38701586'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.02,
#    'place': '27km ENE of Pine Valley, CA',
#    'time': 1600886324930,
#    'updated': 1600892960562,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38701570',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38701570&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 16,
#    'net': 'ci',
#    'code': '38701570',
#    'ids': ',ci38701570,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 17,
#    'dmin': 0.04919,
#    'rms': 0.13,
#    'gap': 129,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 27km ENE of Pine Valley, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2641667, 32.918, 4.45]},
#   'id': 'ci38701570'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '17km E of Ocotillo, CA',
#    'time': 1600859889580,
#    'updated': 1600989545658,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38700914',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38700914&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ci',
#    'code': '38700914',
#    'ids': ',ci38700914,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 30,
#    'dmin': 0.06935,
#    'rms': 0.22,
#    'gap': 59,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 17km E of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.8123333, 32.7455, 10.15]},
#   'id': 'ci38700914'},
#  {'type': 'Feature',
#   'properties': {'mag': 4,
#    'place': '85 km SSW of Nueva Concepción, Guatemala',
#    'time': 1600854580070,
#    'updated': 1607202175040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c002',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c002&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 246,
#    'net': 'us',
#    'code': '6000c002',
#    'ids': ',us6000c002,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 1.025,
#    'rms': 0.34,
#    'gap': 181,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.0 - 85 km SSW of Nueva Concepción, Guatemala'},
#   'geometry': {'type': 'Point', 'coordinates': [-91.6196, 13.496, 41.98]},
#   'id': 'us6000c002'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '15 km NW of Midland, Texas',
#    'time': 1600841079927,
#    'updated': 1607202175040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzyu',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzyu&format=geojson',
#    'felt': 5,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 98,
#    'net': 'us',
#    'code': '6000bzyu',
#    'ids': ',us6000bzyu,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.121,
#    'rms': 0.37,
#    'gap': 42,
#    'magType': 'mb_lg',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 15 km NW of Midland, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-102.1797, 32.1058, 5]},
#   'id': 'us6000bzyu'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.8,
#    'place': '34 km SSW of Ocós, Guatemala',
#    'time': 1600815391099,
#    'updated': 1606599125040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzvq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzvq&format=geojson',
#    'felt': 6,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 357,
#    'net': 'us',
#    'code': '6000bzvq',
#    'ids': ',us6000bzvq,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.675,
#    'rms': 0.96,
#    'gap': 184,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.8 - 34 km SSW of Ocós, Guatemala'},
#   'geometry': {'type': 'Point', 'coordinates': [-92.323, 14.2293, 62.19]},
#   'id': 'us6000bzvq'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.98,
#    'place': '23km SW of Ocotillo Wells, CA',
#    'time': 1600797230570,
#    'updated': 1600970060960,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38699938',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38699938&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'ci',
#    'code': '38699938',
#    'ids': ',ci38699938,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.03087,
#    'rms': 0.17,
#    'gap': 64,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 23km SW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2946667, 32.9846667, 6.33]},
#   'id': 'ci38699938'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '53 km ENE of San Vicente, Mexico',
#    'time': 1600773651828,
#    'updated': 1606599124040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bznb',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bznb&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '6000bznb',
#    'ids': ',ci38699506,us6000bznb,',
#    'sources': ',ci,us,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': None,
#    'dmin': 0.121,
#    'rms': 0.51,
#    'gap': 147,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 53 km ENE of San Vicente, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.717, 31.4988, 10]},
#   'id': 'us6000bznb'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.86,
#    'place': '22km WNW of Ocotillo, CA',
#    'time': 1600767813990,
#    'updated': 1600782397124,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38699426',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38699426&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'ci',
#    'code': '38699426',
#    'ids': ',ci38699426,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.09419,
#    'rms': 0.2,
#    'gap': 81,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 22km WNW of Ocotillo, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2028333, 32.8228333, 9.24]},
#   'id': 'ci38699426'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.7,
#    'place': '49 km NW of Toyah, Texas',
#    'time': 1600757420918,
#    'updated': 1606599123040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000bzkm',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000bzkm&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 112,
#    'net': 'us',
#    'code': '6000bzkm',
#    'ids': ',us6000bzkm,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.261,
#    'rms': 0.38,
#    'gap': 63,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.7 - 49 km NW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.2137, 31.5764, 5]},
#   'id': 'us6000bzkm'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.41,
#    'place': '5km NE of Rancho San Diego, CA',
#    'time': 1600714818780,
#    'updated': 1600798559126,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38698434',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38698434&format=geojson',
#    'felt': 2,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 31,
#    'net': 'ci',
#    'code': '38698434',
#    'ids': ',ci38698434,',
#    'sources': ',ci,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.05896,
#    'rms': 0.26,
#    'gap': 90,
#    'magType': 'ml',
#    'type': 'quarry blast',
#    'title': 'M 1.4 Quarry Blast - 5km NE of Rancho San Diego, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.8915, 32.7761667, -0.36]},
#   'id': 'ci38698434'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.34,
#    'place': '8km NNW of Ocotillo, CA',
#    'time': 1600703760040,
#    'updated': 1600727090156,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38697994',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38697994&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '38697994',
#    'ids': ',ci38697994,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 2,
#    'dmin': 0.1704,
#    'rms': 0.03,
#    'gap': 304,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 8km NNW of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.0123333, 32.8005, 5.46]},
#   'id': 'ci38697994'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.67,
#    'place': '25km SSW of Ocotillo Wells, CA',
#    'time': 1600686504020,
#    'updated': 1614378518569,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38697586',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38697586&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'ci',
#    'code': '38697586',
#    'ids': ',ci38697586,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 25,
#    'dmin': 0.05445,
#    'rms': 0.15,
#    'gap': 102,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 25km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2406667, 32.941, 6.29]},
#   'id': 'ci38697586'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': 'Revilla Gigedo Islands region',
#    'time': 1600678801567,
#    'updated': 1606599120040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqpl',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqpl&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 369,
#    'net': 'us',
#    'code': '7000bqpl',
#    'ids': ',us7000bqpl,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 1.697,
#    'rms': 1.25,
#    'gap': 105,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.9 - Revilla Gigedo Islands region'},
#   'geometry': {'type': 'Point', 'coordinates': [-109.4142, 19.6802, 10]},
#   'id': 'us7000bqpl'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '97 km SW of Altata, Mexico',
#    'time': 1600662953049,
#    'updated': 1606599119040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqnk',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqnk&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 298,
#    'net': 'us',
#    'code': '7000bqnk',
#    'ids': ',us7000bqnk,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 3.944,
#    'rms': 0.91,
#    'gap': 165,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 97 km SW of Altata, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-108.5768, 23.9865, 10]},
#   'id': 'us7000bqnk'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': 'Revilla Gigedo Islands region',
#    'time': 1600662130893,
#    'updated': 1606599119040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqnj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqnj&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '7000bqnj',
#    'ids': ',us7000bqnj,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 1.671,
#    'rms': 0.93,
#    'gap': 89,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - Revilla Gigedo Islands region'},
#   'geometry': {'type': 'Point', 'coordinates': [-109.4273, 19.6478, 10]},
#   'id': 'us7000bqnj'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.52,
#    'place': '17km WNW of Progreso, B.C., MX',
#    'time': 1600634609280,
#    'updated': 1600967448649,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696962',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696962&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 36,
#    'net': 'ci',
#    'code': '38696962',
#    'ids': ',ci38696962,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 24,
#    'dmin': 0.03105,
#    'rms': 0.22,
#    'gap': 129,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 17km WNW of Progreso, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.7578333, 32.6331667, 10.18]},
#   'id': 'ci38696962'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.6,
#    'place': '57 km ENE of San Vicente, Mexico',
#    'time': 1600623062389,
#    'updated': 1606599118040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqiw',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqiw&format=geojson',
#    'felt': 2,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 200,
#    'net': 'us',
#    'code': '7000bqiw',
#    'ids': ',ci38696834,us7000bqiw,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': None,
#    'dmin': 0.136,
#    'rms': 1.07,
#    'gap': 103,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.6 - 57 km ENE of San Vicente, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.6756, 31.4921, 10]},
#   'id': 'us7000bqiw'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.51,
#    'place': '0km NE of El Centro, CA',
#    'time': 1600615709220,
#    'updated': 1600887179288,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696746',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696746&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ci',
#    'code': '38696746',
#    'ids': ',ci38696746,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 21,
#    'dmin': 0.05213,
#    'rms': 0.21,
#    'gap': 86,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 0km NE of El Centro, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.5543333, 32.791, 10.48]},
#   'id': 'ci38696746'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.39,
#    'place': '1km E of El Centro, CA',
#    'time': 1600610366930,
#    'updated': 1600885431930,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696722',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696722&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ci',
#    'code': '38696722',
#    'ids': ',ci38696722,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 18,
#    'dmin': 0.05269,
#    'rms': 0.2,
#    'gap': 126,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 1km E of El Centro, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.5495, 32.7878333, 10.23]},
#   'id': 'ci38696722'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.23,
#    'place': '2km ESE of El Centro, CA',
#    'time': 1600610226040,
#    'updated': 1600885102071,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696714',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696714&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '38696714',
#    'ids': ',ci38696714,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.05242,
#    'rms': 0.19,
#    'gap': 88,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 2km ESE of El Centro, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.5441667, 32.7818333, 10.77]},
#   'id': 'ci38696714'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.76,
#    'place': '32km WSW of Encinitas, CA',
#    'time': 1600608522520,
#    'updated': 1600883481909,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696690',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696690&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 48,
#    'net': 'ci',
#    'code': '38696690',
#    'ids': ',ci38696690,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 36,
#    'dmin': 0.3253,
#    'rms': 0.13,
#    'gap': 186,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 32km WSW of Encinitas, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.6115, 32.9376667, 15.29]},
#   'id': 'ci38696690'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.11,
#    'place': '26km SSW of Ocotillo Wells, CA',
#    'time': 1600602644410,
#    'updated': 1600883077866,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696642',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696642&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'ci',
#    'code': '38696642',
#    'ids': ',ci38696642,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 48,
#    'dmin': 0.02346,
#    'rms': 0.19,
#    'gap': 58,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 26km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2803333, 32.9413333, 8.32]},
#   'id': 'ci38696642'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.34,
#    'place': '1km SE of El Centro, CA',
#    'time': 1600599848950,
#    'updated': 1600808497246,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696594',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696594&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'ci',
#    'code': '38696594',
#    'ids': ',ci38696594,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.04699,
#    'rms': 0.24,
#    'gap': 93,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 1km SE of El Centro, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.5541667, 32.7836667, 8.45]},
#   'id': 'ci38696594'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.49,
#    'place': '1km NNE of El Centro, CA',
#    'time': 1600596371340,
#    'updated': 1600801363849,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455637',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455637&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 34,
#    'net': 'ci',
#    'code': '37455637',
#    'ids': ',ci37455637,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 18,
#    'dmin': 0.05693,
#    'rms': 0.26,
#    'gap': 108,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 1km NNE of El Centro, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.5525, 32.796, 7.34]},
#   'id': 'ci37455637'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '1km ESE of El Centro, CA',
#    'time': 1600596365900,
#    'updated': 1600800975438,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696562',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696562&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ci',
#    'code': '38696562',
#    'ids': ',ci38696562,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.05027,
#    'rms': 0.24,
#    'gap': 93,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 1km ESE of El Centro, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.5501667, 32.7848333, 9.68]},
#   'id': 'ci38696562'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.79,
#    'place': '26km SSW of Ocotillo Wells, CA',
#    'time': 1600586780220,
#    'updated': 1600797393855,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696514',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696514&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'ci',
#    'code': '38696514',
#    'ids': ',ci38696514,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 37,
#    'dmin': 0.02101,
#    'rms': 0.19,
#    'gap': 97,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 26km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2835, 32.9418333, 7.85]},
#   'id': 'ci38696514'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.21,
#    'place': '26km SSW of Ocotillo Wells, CA',
#    'time': 1600586772180,
#    'updated': 1600798235333,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37455621',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37455621&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'ci',
#    'code': '37455621',
#    'ids': ',ci37455621,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 15,
#    'dmin': 0.02384,
#    'rms': 0.15,
#    'gap': 153,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 26km SSW of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2791667, 32.9421667, 8.51]},
#   'id': 'ci37455621'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.67,
#    'place': '18km WNW of Progreso, B.C., MX',
#    'time': 1600580546630,
#    'updated': 1600794310270,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696450',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696450&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 43,
#    'net': 'ci',
#    'code': '38696450',
#    'ids': ',ci38696450,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 28,
#    'dmin': 0.03304,
#    'rms': 0.21,
#    'gap': 129,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 18km WNW of Progreso, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.761, 32.6338333, 9.45]},
#   'id': 'ci38696450'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.08,
#    'place': '11km W of Delta, B.C., MX',
#    'time': 1600574366970,
#    'updated': 1600720311600,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696410',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696410&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 67,
#    'net': 'ci',
#    'code': '38696410',
#    'ids': ',ci38696410,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 28,
#    'dmin': 0.0827,
#    'rms': 0.26,
#    'gap': 132,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 11km W of Delta, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.3098333, 32.3366667, 10.66]},
#   'id': 'ci38696410'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.39,
#    'place': '88km ESE of Maneadero, B.C., MX',
#    'time': 1600571119170,
#    'updated': 1600791502200,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38696378',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38696378&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 88,
#    'net': 'ci',
#    'code': '38696378',
#    'ids': ',ci38696378,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 6,
#    'dmin': 0.1758,
#    'rms': 0.12,
#    'gap': 219,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 88km ESE of Maneadero, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.6603333, 31.5323333, -1.18]},
#   'id': 'ci38696378'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.2,
#    'place': '11 km W of Santa Tecla, El Salvador',
#    'time': 1600554187478,
#    'updated': 1606599115040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bqdw',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bqdw&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 158,
#    'net': 'us',
#    'code': '7000bqdw',
#    'ids': ',us7000bqdw,',
#    'sources': ',us,',
#    'types': ',impact-text,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.706,
#    'rms': 0.1,
#    'gap': 192,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 11 km W of Santa Tecla, El Salvador'},
#   'geometry': {'type': 'Point', 'coordinates': [-89.3847, 13.6888, 10]},
#   'id': 'us7000bqdw'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '36 km SW of Puerto El Triunfo, El Salvador',
#    'time': 1600522325759,
#    'updated': 1606599114040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c0i1',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c0i1&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 298,
#    'net': 'us',
#    'code': '6000c0i1',
#    'ids': ',us6000c0i1,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 1.456,
#    'rms': 0.95,
#    'gap': 174,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 36 km SW of Puerto El Triunfo, El Salvador'},
#   'geometry': {'type': 'Point', 'coordinates': [-88.7889, 13.0447, 67.3]},
#   'id': 'us6000c0i1'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '11 km SW of Mazatán, Mexico',
#    'time': 1600495384162,
#    'updated': 1606599113040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bq4s',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bq4s&format=geojson',
#    'felt': 4,
#    'cdi': 4.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 299,
#    'net': 'us',
#    'code': '7000bq4s',
#    'ids': ',us7000bq4s,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.275,
#    'rms': 0.84,
#    'gap': 140,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 11 km SW of Mazatán, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-92.5161, 14.7767, 66.06]},
#   'id': 'us7000bq4s'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.07,
#    'place': '4km WSW of Imperial, CA',
#    'time': 1600493901970,
#    'updated': 1614273964755,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38695610',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38695610&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'ci',
#    'code': '38695610',
#    'ids': ',ci38695610,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 18,
#    'dmin': 0.08208,
#    'rms': 0.14,
#    'gap': 116,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 4km WSW of Imperial, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.6058333, 32.8285, 9.7]},
#   'id': 'ci38695610'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.24,
#    'place': '15km ESE of Ocotillo, CA',
#    'time': 1600484140130,
#    'updated': 1600716367669,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38695482',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38695482&format=geojson',
# ...
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'us',
#    'code': '7000bh8l',
#    'ids': ',us7000bh8l,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.109,
#    'rms': 0.62,
#    'gap': 60,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 56 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.3723, 31.6671, 5]},
#   'id': 'us7000bh8l'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.8,
#    'place': '1 km W of Pollard, Alabama',
#    'time': 1599145673153,
#    'updated': 1607185759553,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh6x',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh6x&format=geojson',
#    'felt': 151,
#    'cdi': 5.2,
#    'mmi': 4.067,
#    'alert': 'green',
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 301,
#    'net': 'us',
#    'code': '7000bh6x',
#    'ids': ',us7000bh6x,',
#    'sources': ',us,',
#    'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#    'nst': None,
#    'dmin': 0.182,
#    'rms': 0.8,
#    'gap': 78,
#    'magType': 'mwr',
#    'type': 'earthquake',
#    'title': 'M 3.8 - 1 km W of Pollard, Alabama'},
#   'geometry': {'type': 'Point', 'coordinates': [-87.1846, 31.0271, 4]},
#   'id': 'us7000bh6x'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.25,
#    'place': '23km NW of Ocotillo, CA',
#    'time': 1599141992190,
#    'updated': 1599164219837,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369711',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369711&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'ci',
#    'code': '39369711',
#    'ids': ',ci39369711,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 51,
#    'dmin': 0.1039,
#    'rms': 0.21,
#    'gap': 63,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 23km NW of Ocotillo, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.1851667, 32.8648333, 6.47]},
#   'id': 'ci39369711'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.06,
#    'place': '7km W of Progreso, B.C., MX',
#    'time': 1599140807770,
#    'updated': 1599162473010,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369687',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369687&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'ci',
#    'code': '39369687',
#    'ids': ',ci39369687,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 32,
#    'dmin': 0.0946,
#    'rms': 0.26,
#    'gap': 131,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 7km W of Progreso, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.6611667, 32.5721667, 11.45]},
#   'id': 'ci39369687'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '147 km SW of Emiliano Zapata, Mexico',
#    'time': 1599137191635,
#    'updated': 1605642266040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh4q',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh4q&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 271,
#    'net': 'us',
#    'code': '7000bh4q',
#    'ids': ',us7000bh4q,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 2.251,
#    'rms': 1.3,
#    'gap': 221,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 147 km SW of Emiliano Zapata, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-106.07, 18.56, 10]},
#   'id': 'us7000bh4q'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.55,
#    'place': '12km WSW of El Centro, CA',
#    'time': 1599131784500,
#    'updated': 1599164793558,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37299004',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37299004&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 5,
#    'net': 'ci',
#    'code': '37299004',
#    'ids': ',ci37299004,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 2,
#    'dmin': 0.1185,
#    'rms': 0.03,
#    'gap': 317,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 12km WSW of El Centro, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.686, 32.7631667, 2.87]},
#   'id': 'ci37299004'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.8,
#    'place': '22km NW of Ocotillo, CA',
#    'time': 1599131077010,
#    'updated': 1599157285620,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369599',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369599&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'ci',
#    'code': '39369599',
#    'ids': ',ci39369599,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.09883,
#    'rms': 0.16,
#    'gap': 94,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 22km NW of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.1755, 32.8656667, 9.47]},
#   'id': 'ci39369599'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.79,
#    'place': '88km ESE of Maneadero, B.C., MX',
#    'time': 1599128258000,
#    'updated': 1605642266040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369543',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369543&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 120,
#    'net': 'ci',
#    'code': '39369543',
#    'ids': ',ci39369543,us7000bh3w,',
#    'sources': ',ci,us,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1746,
#    'rms': 0.11,
#    'gap': 96,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 88km ESE of Maneadero, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.662, 31.5318333, 11.06]},
#   'id': 'ci39369543'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.64,
#    'place': '23km NW of Ocotillo, CA',
#    'time': 1599127849470,
#    'updated': 1599159360120,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39369535',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39369535&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 41,
#    'net': 'ci',
#    'code': '39369535',
#    'ids': ',ci39369535,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 61,
#    'dmin': 0.1004,
#    'rms': 0.19,
#    'gap': 64,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 23km NW of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.1821667, 32.8625, 6.77]},
#   'id': 'ci39369535'},
#  {'type': 'Feature',
#   'properties': {'mag': 3,
#    'place': '48 km W of Mentone, Texas',
#    'time': 1599105147111,
#    'updated': 1605642265040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh0h',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh0h&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 138,
#    'net': 'us',
#    'code': '7000bh0h',
#    'ids': ',us7000bh0h,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.064,
#    'rms': 0.35,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.0 - 48 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.1057, 31.736, 8.03]},
#   'id': 'us7000bh0h'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.4,
#    'place': '20 km E of La Paz, Mexico',
#    'time': 1599101122910,
#    'updated': 1605642264040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bh03',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bh03&format=geojson',
#    'felt': 6,
#    'cdi': 3.8,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 180,
#    'net': 'us',
#    'code': '7000bh03',
#    'ids': ',us7000bh03,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': 0.511,
#    'rms': 0.72,
#    'gap': 162,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 3.4 - 20 km E of La Paz, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-110.0976, 24.1798, 10]},
#   'id': 'us7000bh03'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.8,
#    'place': '47 km W of Mentone, Texas',
#    'time': 1599055998582,
#    'updated': 1605642262040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgj8',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgj8&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 121,
#    'net': 'us',
#    'code': '7000bgj8',
#    'ids': ',us7000bgj8,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.062,
#    'rms': 0.29,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 47 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.1039, 31.7377, 6.91]},
#   'id': 'us7000bgj8'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '1km NW of El Centro, CA',
#    'time': 1599025263590,
#    'updated': 1599078829270,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39368159',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39368159&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ci',
#    'code': '39368159',
#    'ids': ',ci39368159,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 26,
#    'dmin': 0.05138,
#    'rms': 0.23,
#    'gap': 49,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 1km NW of El Centro, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.565, 32.7965, 12.51]},
#   'id': 'ci39368159'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '47 km W of Mentone, Texas',
#    'time': 1599023915195,
#    'updated': 1605642261040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgbt',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgbt&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'us',
#    'code': '7000bgbt',
#    'ids': ',us7000bgbt,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.058,
#    'rms': 0.38,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 47 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.0994, 31.7371, 5.27]},
#   'id': 'us7000bgbt'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.1,
#    'place': '45 km W of Mentone, Texas',
#    'time': 1599022369510,
#    'updated': 1605642261040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgb9',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgb9&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 148,
#    'net': 'us',
#    'code': '7000bgb9',
#    'ids': ',us7000bgb9,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': 0.044,
#    'rms': 0.68,
#    'gap': 56,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 45 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.072, 31.76, 5]},
#   'id': 'us7000bgb9'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.3,
#    'place': '47 km W of Mentone, Texas',
#    'time': 1599022306611,
#    'updated': 1605642261040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bgb8',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bgb8&format=geojson',
#    'felt': 2,
#    'cdi': 2.7,
#    'mmi': 4.134,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 168,
#    'net': 'us',
#    'code': '7000bgb8',
#    'ids': ',us7000bgb8,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,shakemap,',
#    'nst': None,
#    'dmin': 0.059,
#    'rms': 0.47,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 47 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.099, 31.7235, 8.58]},
#   'id': 'us7000bgb8'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.27,
#    'place': '16km E of Ocotillo, CA',
#    'time': 1599011478030,
#    'updated': 1599072735277,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39368095',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39368095&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'ci',
#    'code': '39368095',
#    'ids': ',ci39368095,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 21,
#    'dmin': 0.07347,
#    'rms': 0.18,
#    'gap': 57,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 16km E of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.8186667, 32.755, 6.93]},
#   'id': 'ci39368095'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.28,
#    'place': '4km ENE of Rancho San Diego, CA',
#    'time': 1598986836650,
#    'updated': 1599078592353,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39367687',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci39367687&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'ci',
#    'code': '39367687',
#    'ids': ',ci39367687,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 19,
#    'dmin': 0.0479,
#    'rms': 0.13,
#    'gap': 88,
#    'magType': 'ml',
#    'type': 'quarry blast',
#    'title': 'M 1.3 Quarry Blast - 4km ENE of Rancho San Diego, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.897, 32.7645, 6.07]},
#   'id': 'ci39367687'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.3,
#    'place': '58 km ENE of San Vicente, Mexico',
#    'time': 1598946094388,
#    'updated': 1604774923040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000bfn0',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000bfn0&format=geojson',
#    'felt': 2,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 168,
#    'net': 'us',
#    'code': '7000bfn0',
#    'ids': ',ci39367079,us7000bfn0,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': None,
#    'dmin': 0.132,
#    'rms': 1.17,
#    'gap': 122,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 58 km ENE of San Vicente, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.6461, 31.4528, 20.51]},
#   'id': 'us7000bfn0'}]

# %%
type(dct['features'])
# Out:
# list

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 2.4,
#   'place': '17 km SE of Ackerly, Texas',
#   'time': 1601152788020,
#   'updated': 1607202180040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson',
#   'felt': 3,
#   'cdi': 3.1,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 90,
#   'net': 'us',
#   'code': '6000c1qf',
#   'ids': ',us6000c1qf,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 0.315,
#   'rms': 0.36,
#   'gap': 28,
#   'magType': 'mb_lg',
#   'type': 'earthquake',
#   'title': 'M 2.4 - 17 km SE of Ackerly, Texas'},
#  'geometry': {'type': 'Point', 'coordinates': [-101.5925, 32.4053, 1.21]},
#  'id': 'us6000c1qf'}

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 2.4,
#   'place': '17 km SE of Ackerly, Texas',
#   'time': 1601152788020,
#   'updated': 1607202180040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson',
#   'felt': 3,
#   'cdi': 3.1,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 90,
#   'net': 'us',
#   'code': '6000c1qf',
#   'ids': ',us6000c1qf,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 0.315,
#   'rms': 0.36,
#   'gap': 28,
#   'magType': 'mb_lg',
#   'type': 'earthquake',
#   'title': 'M 2.4 - 17 km SE of Ackerly, Texas'},
#  'geometry': {'type': 'Point', 'coordinates': [-101.5925, 32.4053, 1.21]},
#  'id': 'us6000c1qf'}

# %% [markdown]
# Schauen wir uns das erste Element an

# %%
for key in dct['features'][0]:
    print(key)
# Out:
# type
# properties
# geometry
# id

# %%
dct['features'][0]['properties']
# Out:
# {'mag': 2.4,
#  'place': '17 km SE of Ackerly, Texas',
#  'time': 1601152788020,
#  'updated': 1607202180040,
#  'tz': None,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c1qf',
#  'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000c1qf&format=geojson',
#  'felt': 3,
#  'cdi': 3.1,
#  'mmi': None,
#  'alert': None,
#  'status': 'reviewed',
#  'tsunami': 0,
#  'sig': 90,
#  'net': 'us',
#  'code': '6000c1qf',
#  'ids': ',us6000c1qf,',
#  'sources': ',us,',
#  'types': ',dyfi,origin,phase-data,',
#  'nst': None,
#  'dmin': 0.315,
#  'rms': 0.36,
#  'gap': 28,
#  'magType': 'mb_lg',
#  'type': 'earthquake',
#  'title': 'M 2.4 - 17 km SE of Ackerly, Texas'}

# %% [markdown]
# Lesen wir folgendes aus:
# 1. Type
# 2. Magnitude
# 4. Örtlichkeit
# 5. Time

# %%
earthquakes = []

for elem in dct['features']:
    
    t = elem['properties']['type']
    m = elem['properties']['mag']
    p = elem['properties']['place']
    tm = elem['properties']['time']
    
    mini_dict = {'Type': t,
                 'Mag': m,
                 'Place': p,
                 'Time': tm}
    
    earthquakes.append(mini_dict)

# %%
earthquakes[:3]
# Out:
# [{'Type': 'earthquake',
#   'Mag': 2.4,
#   'Place': '17 km SE of Ackerly, Texas',
#   'Time': 1601152788020},
#  {'Type': 'earthquake',
#   'Mag': 2.99,
#   'Place': '87km ESE of Maneadero, B.C., MX',
#   'Time': 1601147573490},
#  {'Type': 'earthquake',
#   'Mag': 2.07,
#   'Place': '15km SSE of Primo Tapia, B.C., MX',
#   'Time': 1601085758960}]

# %% [markdown]
# ### Erste Erfahrung mit Pandas

# %%
pd.DataFrame(earthquakes)
# Out:
#              Type   Mag                               Place           Time
# 0      earthquake  2.40          17 km SE of Ackerly, Texas  1601152788020
# 1      earthquake  2.99     87km ESE of Maneadero, B.C., MX  1601147573490
# 2      earthquake  2.07   15km SSE of Primo Tapia, B.C., MX  1601085758960
# 3      earthquake  3.10  56 km S of Whites City, New Mexico  1601050250095
# 4      earthquake  2.90  56 km S of Whites City, New Mexico  1601050163468
# ..            ...   ...                                 ...            ...
# 167    earthquake  3.10           45 km W of Mentone, Texas  1599022369510
# 168    earthquake  3.30           47 km W of Mentone, Texas  1599022306611
# 169    earthquake  1.27              16km E of Ocotillo, CA  1599011478030
# 170  quarry blast  1.28     4km ENE of Rancho San Diego, CA  1598986836650
# 171    earthquake  3.30    58 km ENE of San Vicente, Mexico  1598946094388
#
# [172 rows x 4 columns]

# %%
df = pd.DataFrame(earthquakes)

# %% [markdown]
# Speichern wir das ab.

# %%
df.to_csv('erdbeben.csv')

# %% [markdown]
# # Üben wir das Ganze! Weiter zur Übung 1.
