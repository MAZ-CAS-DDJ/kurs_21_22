# %% [markdown]
# # Google Maps

# %% [markdown]
# **Inhalt:** Zwei Anwendungen mit Google Maps in Geopandas
#
# **Nötige Skills**
# - Requests
# - Geopandas Basics und Plotting
#
# **Lernziele**
# - Einfache Anwendung und Kennenlernen der Google Maps API

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import geopandas as gpd

# %%
import requests

# %%
import shapely

# %%
from shapely.geometry import Point, LineString

# %%
from IPython.display import Image

# %%
import os

# %%
import polyline

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0. API einrichten

# %% [markdown]
# Wir gehen hier nicht im Detail darauf ein, welche Schritte notwendig sind.
#
# Die wichtigsten Eckpunkte:
#
# 1. Zugang einrichten auf https://console.cloud.google.com/
# 1. Projekt definieren
# 1. API-Key generieren
# 1. Bestimmte API's freischalten

# %% [markdown]
# Am Schluss sollte das ungefähr so aussehen:

# %%
Image("dataprojects/GoogleMaps/google-console.png")

# %% [markdown]
# ### API-Key

# %% [markdown]
# Und ihr solltet einen **API-Key** haben. Am besten speichert ihr den als Systemvariable:
#
# (wie das geht, steht hier: https://www.nylas.com/blog/making-use-of-environment-variables-in-python/)

# %%
api_key = "xxxxxxx"

# %% [markdown]
# ## 1. Geo-Koordinaten
#
# Mit der Google Maps Api fragen wir einfache Geokoordinaten ausgehend von einer Adresse ab.
#
# Infos zur Geocoding API:
# - https://developers.google.com/maps/documentation/geocoding/start
# - https://developers.google.com/maps/documentation/geocoding/overview
#
#
# ### Das Beispiel
#
# Flüge ab Zürich in Europäische Destinationen: Strecken nach Anteil der Passagiere visualisieren.

# %% [markdown]
# ### Daten laden

# %%
df = pd.read_excel('dataprojects/GoogleMaps/ZRH-Destinations-Europe.xlsx')
# Out:
# /Users/simon/opt/anaconda3/envs/CAS-Datenjournalismus/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head(5)
# Out:
#    Rang      Destination Kuerzel  Sitzplätze  Prozent Status
# 0     1  London Heathrow     LHR       15490     6.15   Comp
# 1     2             Wien     VIE       12928     5.13   Mono
# 2     3        Amsterdam     AMS       11786     4.68   Comp
# 3     4        Frankfurt     FRA       10542     4.19   Mono
# 4     5             Genf     GVA        9751     3.87   Mono

# %%
df.shape
# Out:
# (30, 6)

# %% [markdown]
# ### API Anfragen

# %% [markdown]
# Wir benutzen das Flughafenkürzel, um eine Abfrage nach dem folgenden Schema zu machen (Bsp London Heathrow, LHR)

# %% [markdown]
# `https://maps.googleapis.com/maps/api/geocode/json?address=LHR_Airport`

# %%
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?address='

# %%
def get_coordinates(row):
    url = base_url + row['Kuerzel'] + '_Airport' + '&key=' + api_key
    response = requests.get(url)
    json = response.json()
    lat = json['results'][0]['geometry']['location']['lat']
    lng = json['results'][0]['geometry']['location']['lng']
    print(row['Kuerzel'], json['status'])
    s = pd.Series([lat, lng], index=['lat', 'lng'])
    
    return s

# %%
df[['lat', 'lng']] = df.apply(get_coordinates, axis=1)
# Out:
# LHR
# OK
# VIE
# OK
# AMS
# OK
# FRA
# OK
# GVA
# OK
# DUS
# OK
# HAM
# OK
# TXL
# OK
# CDG
# OK
# MAD
# OK
# BCN
# OK
# MUC
# OK
# LCY
# OK
# FCO
# OK
# LIS
# OK
# CPH
# OK
# IST
# OK
# ARN
# OK
# ATH
# OK
# BRU
# OK
# MXP
# OK
# CGN
# OK
# WAW
# OK
# BEG
# OK
# PRG
# OK
# NCE
# OK
# VCE
# OK
# BUD
# OK
# HAJ
# OK
# STR
# OK

# %%
df
# Out:
#     Rang              Destination Kuerzel  Sitzplätze  Prozent Status  \
# 0      1          London Heathrow     LHR       15490     6.15   Comp
# 1      2                     Wien     VIE       12928     5.13   Mono
# 2      3                Amsterdam     AMS       11786     4.68   Comp
# 3      4                Frankfurt     FRA       10542     4.19   Mono
# 4      5                     Genf     GVA        9751     3.87   Mono
# 5      6               Düsseldorf     DUS        9206     3.66   Mono
# 6      7                  Hamburg     HAM        9200     3.65   Comp
# 7      8             Berlin Tegel     TXL        9083     3.61   Comp
# 8      9  Paris Charle de Ggaulle     CDG        8719     3.46   Comp
# 9     10           Madrid Barajas     MAD        7038     2.79   Comp
# 10    11        Barcelona El Prat     BCN        6411     2.55   Comp
# 11    12                  München     MUC        6188     2.46   Mono
# 12    13              London City     LCY        6187     2.46   Comp
# 13    14            Rom Fiumicino     FCO        6182     2.45   Comp
# 14    15                 Lissabon     LIS        6078     2.41   Comp
# 15    16               Kopenhagen     CPH        5054     2.01   Comp
# 16    17                 Istanbul     IST        4899     1.95   Comp
# 17    18                Stockholm     ARN        4893     1.94   Comp
# 18    19                    Athen     ATH        4824     1.92   Comp
# 19    20                  Brüssel     BRU        4720     1.87   Mono
# 20    21         Mailand-Malpensa     MXP        4441     1.76   Mono
# 21    22                     Köln     CGN        4260     1.69   Mono
# 22    23                 Warschau     WAW        3809     1.51   Comp
# 23    24                  Belgrad     BEG        3756     1.49   Comp
# 24    25                     Prag     PRG        3597     1.43   Comp
# 25    26                    Nizza     NCE        3555     1.41   Comp
# 26    27                  Venedig     VCE        3480     1.38   Comp
# 27    28                 Budapest     BUD        3138     1.25   Mono
# 28    29                 Hannover     HAJ        2974     1.18   Mono
# 29    30                Stuttgart     STR        2628     1.04   Comp
#
#           lat        lng
# 0   51.470022  -0.454296
# 1   48.112612  16.575514
# 2   52.310539   4.768274
# 3   50.037933   8.562152
# 4   46.236979   6.109089
# 5   51.287615   6.766791
# 6   53.633622   9.997413
# 7   52.558833  13.288437
# 8   49.009674   2.547966
# 9   40.498332  -3.567598
# 10  41.297445   2.083294
# 11  48.350968  11.776435
# 12  51.504844   0.049518
# 13  41.803427  12.251893
# 14  38.775594  -9.135367
# 15  55.612322  12.647225
# 16  41.276820  28.730173
# 17  59.649762  17.923781
# 18  37.935647  23.948416
# 19  50.900999   4.485574
# 20  45.630063   8.725531
# 21  50.866623   7.141243
# 22  52.167237  20.967891
# 23  44.820298  20.293141
# 24  50.101791  14.263181
# 25  43.659769   7.214821
# 26  45.504456  12.339970
# 27  47.438459  19.252296
# 28  52.463012   9.684618
# 29  48.687637   9.205576

# %% [markdown]
# Ergebnis zwischenspeichern

# %%
df.to_csv('dataprojects/GoogleMaps/Airport-coordinates.csv', index=False)

# %% [markdown]
# ### Strecken plotten

# %% [markdown]
# #### Hintergrundkarte laden:
#
# Eine Karte mit den Europäischen Ländern.

# %%
gdf_europe = gpd.read_file("dataprojects/GoogleMaps/europe.geojson")

# %%
gdf_europe.head()
# Out:
#    FID FIPS ISO2 ISO3   UN                    NAME   AREA  POP2005  REGION  \
# 0  0.0   AJ   AZ  AZE   31              Azerbaijan   8260  8352021     142
# 1  0.0   AL   AL  ALB    8                 Albania   2740  3153731     150
# 2  0.0   AM   AM  ARM   51                 Armenia   2820  3017661     142
# 3  0.0   BK   BA  BIH   70  Bosnia and Herzegovina   5120  3915238     150
# 4  0.0   BU   BG  BGR  100                Bulgaria  11063  7744591     150
#
#    SUBREGION     LON     LAT  \
# 0        145  47.395  40.430
# 1         39  20.068  41.143
# 2        145  44.563  40.534
# 3         39  17.786  44.169
# 4        151  25.231  42.761
#
#                                             geometry
# 0  MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 1  POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 2  MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...
# 3  POLYGON ((17.64984 42.88908, 17.57853 42.94382...
# 4  POLYGON ((27.87917 42.84110, 27.89500 42.80250...

# %% [markdown]
# #### Flughafenkoordinaten laden:

# %%
df = pd.read_csv('dataprojects/GoogleMaps/Airport-coordinates.csv')

# %%
df.head(5)
# Out:
#    Rang      Destination Kuerzel  Sitzplätze  Prozent Status        lat  \
# 0     1  London Heathrow     LHR       15490     6.15   Comp  51.470022
# 1     2             Wien     VIE       12928     5.13   Mono  48.112612
# 2     3        Amsterdam     AMS       11786     4.68   Comp  52.310539
# 3     4        Frankfurt     FRA       10542     4.19   Mono  50.037933
# 4     5             Genf     GVA        9751     3.87   Mono  46.236979
#
#          lng
# 0  -0.454296
# 1  16.575514
# 2   4.768274
# 3   8.562152
# 4   6.109089

# %% [markdown]
# #### Geometrien definieren

# %%
df['zielpunkt'] = df.apply(lambda row: Point(row['lng'], row['lat']), axis=1)

# %%
#Zurich coordinates
zrh_lat = 47.458217
zrh_lng = 8.555476

# %%
df['verbindung'] = df.apply(lambda row: LineString([Point(row['lng'], row['lat']), Point(zrh_lng, zrh_lat)]), axis=1)

# %% [markdown]
# #### Geodatenframe erstellen

# %%
gdf = gpd.GeoDataFrame(df, geometry='zielpunkt')

# %%
gdf.crs = {'init': 'epsg:4326'}
# Out:
# /Users/simon/opt/anaconda3/envs/CAS-Datenjournalismus/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
gdf = gdf.to_crs(gdf_europe.crs)

# %%
gdf.head()
# Out:
#    Rang      Destination Kuerzel  Sitzplätze  Prozent Status        lat  \
# 0     1  London Heathrow     LHR       15490     6.15   Comp  51.470022
# 1     2             Wien     VIE       12928     5.13   Mono  48.112612
# 2     3        Amsterdam     AMS       11786     4.68   Comp  52.310539
# 3     4        Frankfurt     FRA       10542     4.19   Mono  50.037933
# 4     5             Genf     GVA        9751     3.87   Mono  46.236979
#
#          lng                  zielpunkt  \
# 0  -0.454296  POINT (-0.45430 51.47002)
# 1  16.575514  POINT (16.57551 48.11261)
# 2   4.768274   POINT (4.76827 52.31054)
# 3   8.562152   POINT (8.56215 50.03793)
# 4   6.109089   POINT (6.10909 46.23698)
#
#                                           verbindung
# 0  LINESTRING (-0.4542955 51.4700223, 8.555476000...
# 1  LINESTRING (16.5755139 48.1126125, 8.555476000...
# 2  LINESTRING (4.7682744 52.3105386, 8.5554760000...
# 3  LINESTRING (8.562151799999999 50.0379326, 8.55...
# 4  LINESTRING (6.109088799999999 46.2369794, 8.55...

# %% [markdown]
# #### Plot vorbereiten

# %%
destination_size = df['Prozent'] * 70

# %%
line_size = df['Prozent'] * 1.5

# %% [markdown]
# #### Der eigentliche Plot

# %%
# Europakarte
ax = gdf_europe.plot(
    figsize=(18,18),
    color='lightgrey',
    edgecolor='white'
)

# Flughäfen als Punkte
gdf.plot(ax=ax, markersize=destination_size, alpha=0.7)

# Strecken als Linien
gdf.set_geometry('verbindung').plot(ax=ax, linewidth=line_size, alpha=0.7)

ax.set_title("Flugstrecken und Volumen ab Zürich Flughafen")
# Out:
# Text(0.5, 1.0, 'Flugstrecken und Volumen ab Zürich Flughafen')

# %% [markdown]
# ## 2. Wegstrecken
#
# Mit der Google-Maps-Api fragen wir nach einer Wegstrecke zwischen zwei Punkten.
#
# Infos zur Google Directions API:
#
# - https://developers.google.com/maps/documentation/directions/get-directions
# - https://developers.google.com/maps/documentation/directions/quickstart
#
#
# ### Das Beispiel
#
# Weg von Zermatt zum MAZ, mit Bahn und zu Fuss.

# %% [markdown]
# ### Daten beschaffen

# %%
base_url = 'https://maps.googleapis.com/maps/api/directions/json?'

# %%
origin = "Zermatt, Switzerland"
destination = "Murbacherstrasse 3, Luzern, Switzerland"

# %% [markdown]
# Modes:
#
# - DRIVING (default)
# - WALKING
# - TRANSIT (i.e. public transport)
# - ...

# %%
mode = "transit"

# %%
transit_mode = "rail"

# %%
url = base_url + "origin=" + origin + "&destination=" + destination + "&mode=" + mode + "&transit_mode=" + transit_mode + "&key=" + api_key

# %%
response = requests.get(url)

# %%
json = response.json()

# %%
json['status']
# Out:
# 'OK'

# %% [markdown]
# ### Daten umstrukturieren

# %% [markdown]
# Die Reise ist in verschiedene Schritte ("Legs") unterteilt...

# %%
route = json['routes'][0]['legs'][0]

# %%
route
# Out:
# {'arrival_time': {'text': '2:07pm',
#   'time_zone': 'Europe/Zurich',
#   'value': 1635509264},
#  'departure_time': {'text': '10:37am',
#   'time_zone': 'Europe/Zurich',
#   'value': 1635496620},
#  'distance': {'text': '244 km', 'value': 243917},
#  'duration': {'text': '3 hours 31 mins', 'value': 12644},
#  'end_address': 'Murbacherstrasse 3, 6003 Luzern, Switzerland',
#  'end_location': {'lat': 47.0485268, 'lng': 8.3089475},
#  'start_address': '3920 Zermatt, Switzerland',
#  'start_location': {'lat': 46.0248306, 'lng': 7.748230899999999},
#  'steps': [{'distance': {'text': '34.9 km', 'value': 34904},
#    'duration': {'text': '1 hour 9 mins', 'value': 4140},
#    'end_location': {'lat': 46.2939506, 'lng': 7.8816509},
vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/ch-zurich-train.png',
#       'name': 'Train',
#       'type': 'HEAVY_RAIL'}},
#     'num_stops': 7},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '33 m', 'value': 33},
#    'duration': {'text': '1 min', 'value': 37},
#    'end_location': {'lat': 46.2940741, 'lng': 7.881488900000001},
#    'html_instructions': 'Walk to Visp',
#    'polyline': {'points': 'cxpyGgjbo@?WK?M??T'},
#    'start_location': {'lat': 46.2939387, 'lng': 7.881475499999999},
#    'steps': [{'distance': {'text': '9 m', 'value': 9},
#      'duration': {'text': '1 min', 'value': 12},
#      'end_location': {'lat': 46.2939361, 'lng': 7.881596200000001},
#      'html_instructions': 'Head <b>east</b><div style="font-size:0.9em">Take the stairs</div>',
#      'polyline': {'points': 'cxpyGgjbo@?W'},
#      'start_location': {'lat': 46.2939387, 'lng': 7.881475499999999},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '15 m', 'value': 15},
#      'duration': {'text': '1 min', 'value': 14},
#      'end_location': {'lat': 46.2940731, 'lng': 7.8816014},
#      'html_instructions': 'Take the pedestrian tunnel',
#      'polyline': {'points': 'cxpyG_kbo@K?M?'},
#      'start_location': {'lat': 46.2939361, 'lng': 7.881596200000001},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '9 m', 'value': 9},
#      'duration': {'text': '1 min', 'value': 11},
#      'end_location': {'lat': 46.2940741, 'lng': 7.881488900000001},
#      'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Take the stairs</div><div style="font-size:0.9em">Destination will be on the left</div>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': '}xpyG_kbo@?T'},
#      'start_location': {'lat': 46.2940731, 'lng': 7.8816014},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '95.5 km', 'value': 95494},
#    'duration': {'text': '57 mins', 'value': 3420},
#    'end_location': {'lat': 46.9480069, 'lng': 7.435881600000001},
#    'html_instructions': 'Long distance train towards Romanshorn',
#    'polyline': {'points': 'yxpyGgnbo@?LCfBKpJK|FAl@Al@EvBElAE|@ALAPC`@?@IlAO`B?BK`AKx@Ef@Il@Ij@Kl@ETEXc@bCEJOl@]xAo@`CCJSj@Y|@KXg@lAo@vAk@nAuDbIaAxB_ApBUh@KVOX_ApBqBhEm@nAEJu@xAw@`Bk@nAi@hAiA~Bm@nACF_BlD[v@CFUh@Sh@Uh@IRITQl@e@vAM`@M`@_@nAYbAITOl@kApEw@jDYtAm@lCOp@c@lBOp@YxAa@tBi@tCg@tCSpAUdBM~@Ir@e@~E[lDOpBM~AKlAOjBWhDEf@MtC_@jGOfCOjC]dFOvBE^MvASvB]hCCRMjAEV[hBQrAAD[rAi@nCg@pBa@|Ag@bBi@bB}@hCu@vBgSnf@s@dBaTfd@qKtT_BhDWf@kv@p`Bay@xn@]XiQ`NyjAp|@]Vm`CdhB_@X}v@ll@ubBtmAsj@re@eWbV]\\cDzCu]z[mN|LmZnX{QbRcs@ll@yRhQ_@Z_TjRyNtPwOjR]^cg@jm@an@pz@sl@zw@kVvXo[nXkQzOsSvGa@LqInCoZpCgN`BmV{@ax@Bqd@MeIZ_i@bEc@D{S`BumCn{@{b@fLuKdC{Jp@c@Bo^dCyLr@SEib@sGuEoAyEoA}^qMwHmCkYuLeD}@}Bi@uEs@iEo@iEo@oK_BiBWwG_AMCeDg@iEo@uDk@qCa@}@SmAOuASwASOEMCCAs@KWEYGYE}@SeAWgEsAe@Oc@OiBo@kGsB
_APyE~@qAVkB^cARC?aEx@uBb@c@HMBuAXqDr@_Dl@}Bd@c@HQB}Cp@G@o@LE@wAXs@LyBb@yAXkB^gCf@mAVC?g@L{Cl@sE|@a@HgDp@kFbAeB\\y@PcARiB^yCl@{Dv@oATmDt@_F~@{AZqDt@aARm@LuBb@y@NUFUDsAXC?wAV}B`@{@ReDl@o@NiAR}Bd@e@LUDSDmCh@E@mCf@uHzA ...
#    'start_location': {'lat': 46.2940492, 'lng': 7.882119299999998},
#    'transit_details': {'arrival_stop': {'location': {'lat': 46.9480069,
#       'lng': 7.435881600000001},
#      'name': 'Bern'},
#     'arrival_time': {'text': '12:54pm',
#      'time_zone': 'Europe/Zurich',
#      'value': 1635504840},
#     'departure_stop': {'location': {'lat': 46.2940492,
#       'lng': 7.882119299999998},
#      'name': 'Visp'},
#     'departure_time': {'text': '11:57am',
#      'time_zone': 'Europe/Zurich',
#      'value': 1635501420},
#     'headsign': 'Romanshorn',
#     'line': {'agencies': [{'name': 'Schweizerische Bundesbahnen SBB',
#        'phone': '011 41 900 300 300',
#        'url': 'http://www.sbb.ch/en/timetable'}],
#      'color': '#ec0000',
#      'short_name': 'IC8',
#      'text_color': '#ffffff',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/ch-zurich-train.png',
#       'name': 'Long distance train',
#       'type': 'LONG_DISTANCE_TRAIN'}},
#     'num_stops': 3},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '50 m', 'value': 50},
#    'duration': {'text': '1 min', 'value': 44},
#    'end_location': {'lat': 46.94855829999999, 'lng': 7.436520199999999},
#    'html_instructions': 'Walk to Bern',
#    'polyline': {'points': 'cqp}Gqnkl@?BUFC@WH[H@F'},
#    'start_location': {'lat': 46.9481826, 'lng': 7.436733800000001},
#    'steps': [{'distance': {'text': '2 m', 'value': 2},
#      'duration': {'text': '1 min', 'value': 2},
#      'end_location': {'lat': 46.9481785, 'lng': 7.4367102},
#      'html_instructions': 'Head <b>west</b> toward <b>Welle</b><div style="font-size:0.9em">Take the stairs</div>',
#      'polyline': {'points': 'cqp}Gqnkl@?B'},
#      'start_location': {'lat': 46.9481826, 'lng': 7.436733800000001},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '45 m', 'value': 45},
#      'duration': {'text': '1 min', 'value': 38},
#      'end_location': {'lat': 46.948567, 'lng': 7.436559300000001},
#      'html_instructions': 'Take the pedestrian overpass',
#      'polyline': {'points': 'cqp}Gmnkl@UFC@WH[H'},
#      'start_location': {'lat': 46.9481785, 'lng': 7.4367102},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '3 m', 'value': 3},
#      'duration': {'text': '1 min', 'value': 4},
#      'end_location': {'lat': 46.94855829999999, 'lng': 7.436520199999999},
#      'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Take the stairs</div>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'qsp}Gomkl@@F'},
#      'start_location': {'lat': 46.948567, 'lng': 7.436559300000001},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'},
#   {'distance': {'text':
Bg@Qa@OgOqFeKeC}LoB}MwAoNo@sGEm@?}QB{EOG?qCUuIkBiFeBsAm@o@[eAk@QKsA{@wAaAyAkAkC_CuB}BQQQS_AkAe@k@s@aAe@s@SYCEU_@Yc@m@cAg@}@m@iAOWcAwBa@aAc@aAM][w@GMK[M]EMWq@a@oAe@}Ae@yA[gAi@oBOg@Ma@c@yAuBoHqCoJMg@Uu@[gAW}@e@}AGSQq@W{@Qk@Qm@Ok@Qi@Qk@Qm@Oi@Uw@Uy@Qi@W_AW{@u@oC[iAS{@AGOi@WiA]yA]aBI_@q@gDg@qC?AQaAMw@Ki@SoAa@_Ce@uCKy@a@wC]sBYcBW_B_@iBAGYyAYyA]yBKi@SiAGa@kAcHuAsIUoAQeASsAG[E[ESIc@Ii@Ie@Mw@Kk@E]Ko@Ic@G]YiBo@wDQiAYcBa@_C[mB?Cc@mCGYUwASoAOw@EUMy@SkASwAaDeSg@wCAA}@wFi@}CUyAYeBEk@Ey@IiAQ_B_@gC_@wB_@}BY}AOkACYEk@CcAAi@?g@@i@Bc@FiABWFo@Fk@P}@Ty@Rm@To@^s@Zi@DGVa@a@f@uGxImHxJyEnGgCjDSXUVs@`Am@x@{@hAoLlOqC~DDOt@eArAoBpFkHxDaFzBuCh@u@LQV]hCkDpEiGrd@en@hBiCbEqF\\a@JMvA_B`EcEfHkHtCuCBCpAsApEmEvCuCTURS~B_CRSRSLMl@m@xAwAnCmCbEcEhCgCnEoErDqDpAqAPQPQvBwBpBoBrHqHv@w@|C{C~@aANOnDkDtBwBTWZ[h@i@FGFGvCuBh@]~@o@dBeAHELINKHEtBoAJIt@i@pLkId@]|@g@HG@?JGrAq@~Aw@p@_@~DmB|Ao@fD{AjEkBvLkF`Ac@zAo@@ATKHEHCTKbBu@NIPGhEmB|V{K|I}DtLkFtCoAJGJE ...
#    'start_location': {'lat': 46.9483506, 'lng': 7.4354662},
#    'transit_details': {'arrival_stop': {'location': {'lat': 47.0484679,
#       'lng': 8.3100992},
#      'name': 'Luzern'},
#     'arrival_time': {'text': '2:02pm',
#      'time_zone': 'Europe/Zurich',
#      'value': 1635508920},
#     'departure_stop': {'location': {'lat': 46.9483506, 'lng': 7.4354662},
#      'name': 'Bern'},
#     'departure_time': {'text': '1:01pm',
#      'time_zone': 'Europe/Zurich',
#      'value': 1635505260},
#     'headsign': 'Luzern',
#     'line': {'agencies': [{'name': 'Schweizerische Bundesbahnen SBB',
#        'phone': '011 41 900 300 300',
#        'url': 'http://www.sbb.ch/en/timetable'}],
#      'color': '#ec0000',
#      'short_name': 'IR15',
#      'text_color': '#ffffff',
#      'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/ch-zurich-train.png',
#       'name': 'Train',
#       'type': 'HEAVY_RAIL'}},
#     'num_stops': 3},
#    'travel_mode': 'TRANSIT'},
#   {'distance': {'text': '0.4 km', 'value': 431},
#    'duration': {'text': '5 mins', 'value': 326},
#    'end_location': {'lat': 47.0485268, 'lng': 8.3089475},
#    'html_instructions': 'Walk to Murbacherstrasse 3, 6003 Luzern, Switzerland',
#    'polyline': {'points': '}cd~Giavq@aI~@Mf@BbALANCLE\\Gf@Id@E^E@?\\Cb@GVCXhAPn@'},
#    'start_location': {'lat': 47.04846999999999, 'lng': 8.3101307},
#    'steps': [{'building_level': {'number': 0},
#      'distance': {'text': '0.2 km', 'value': 198},
#      'duration': {'text': '2 mins', 'value': 149},
#      'end_location': {'lat': 47.05015239999999, 'lng': 8.309605399999999},
#      'html_instructions': 'Walk for 200&nbsp;m',
#      'polyline': {'points': '}cd~Giavq@aI~@Mf@'},
#      'start_location': {'lat': 47.04846999999999, 'lng': 8.3101307},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '25 m', 'value': 25},
#      'duration': {'text': '1 min', 'value': 18},
#      'end_location': {'lat': 47.05013049999999, 'lng': 8.3092747},
#      'html_instructions': 'Head <b>west</b> toward <b>Zentralstrasse</b>/<wbr/><b>Route 4</b>',
#      'polyline': {'points': 'mnd~Ga~uq@BbA'},
#      'start_location': {'lat': 47.05015239999999, 'lng': 8.309605399999999},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '0.2 km', 'value': 155},
#      'duration': {'text': '2 mins', 'value': 114},
#      'end_location': {'lat': 47.0487486, 'lng': 8.3095552},
#      'html_instructions': 'Turn <b>left</b> onto <b>Zentralstrasse</b>/<wbr/><b>Route 4</b>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'ind~G}{uq@LANCLE\\Gf@Id@E^E@?\\Cb@GVC'},
#      'start_location': {'lat': 47.05013049999999, 'lng': 8.3092747},
#      'travel_mode': 'WALKING'},
#     {'distance': {'text': '53 m', 'value': 53},
#      'duration': {'text': '1 min', 'value': 45},
#      'end_location': {'lat': 47.0485268, 'lng': 8.3089475},
#      'html_instructions': 'Turn <b>right</b> onto <b>Murbacherstrasse</b><div style="font-size:0.9em">Destination will be on the left</div>',
#      'maneuver': 'turn-right',
#      'polyline': {'points': 'ued~Gw}uq@XhAPn@'},
#      'start_location': {'lat': 47.0487486, 'lng': 8.3095552},
#      'travel_mode': 'WALKING'}],
#    'travel_mode': 'WALKING'}],
#  'traffic_speed_entry': [],
#  'via_waypoint': []}

# %%
route['distance']['text']
# Out:
# '244 km'

# %%
route['duration']['text']
# Out:
# '3 hours 31 mins'

# %% [markdown]
# ... und diese wiederum in einzelne Schritte ("Steps"):

# %%
route['steps'][0]
# Out:
# {'distance': {'text': '34.9 km', 'value': 34904},
#  'duration': {'text': '1 hour 9 mins', 'value': 4140},
#  'end_location': {'lat': 46.2939506, 'lng': 7.8816509},
#  'html_instructions': 'Train towards Visp',
#  'polyline': {'points': 'ef|wGmihn@@C{@k@q@c@KIKK[[QOOOGGa@a@ECQSMMKGMKMOeAqAaEeFEGCCIKII[c@IKMSKSOYMYO_@GOY{@Me@K_@WgAEMEMOWKMKKCAKEOEMEMAMAGAe@Ba@EOCMC_@OSOOKOMMQ}@yA?A{AmCqAsBw@oAKWIU?CIYKi@COEKEIGKMKKIc@]g@]e@WIIIGGG]a@SUQOUOSKUEMCM?I?a@@s@LqAJs@EUK[Mo@e@SQGGYa@Q[]o@CEOYKMKOOQe@[sCiBg@UWIC?_@?C?]DYDMDOBYBQ@Q?OAMCi@KkAUOEOEMMOMIKOSQ[Uc@a@u@WOSKi@Og@Ac
WU_@UQKMOSc@Mi@Ec@AGAYA{CCwE?cDGq@Ka@Mk@Wg@EGk@aAGMm@w@_@_@_@]WMY[IKKOQa@M_@?AMg@EWEk@Cm@AGCc@AUA]Ca@AQK[Se@QUQOYO[I_@Ga@GWISE[IQAKCU?Q?QFWPi@^i@^[LUJQBW?Q?O?G?UAUCQEWG]Ow@g@mAeA_@YMGMCOCKCYAU?UDQFOFOH]JSBQBO?QAKCOGKGMKMGWESCSAO@c@LWH]DS@SAOCQCIEq@SaCs@_@K]Q_@WIIk@q@QSUWiA}AGKWYMMKICE[OAAcAUwA]qCu@cG}AQEi@KaAOm@Kc@Ic@Iy@Sk@QwDgAm@OMEEAS?Y@YBUDYDSBS@o@Cc@AgAIw@Gc@Im@YUSi@a@MKq@m@YQWKMEEAWAe@FA@w@PkA^GB[LOFWFEBe@LY@]?i@Mo@YQKOKq@k@u@u@}@eA}@uAe@k@CC_@c@k@_@_Ac@SEu@OqAOmAKOAk@Eg@?q@F}@Ju@Ly@NeAZcAZiAV[FK@g@Fg@@k@Aw@G}@M[IC?u@QUG_@Go@MSAy@GqBC_BHS@s@Bw@Je@DgALsAB{@?a@Ai@Iw@We@UkAm@cB{@e@Yk@Wc@Q]G}@Gi@EWEm@Oo@SKEaA_@k@OsAWmASeBYKAiD ...
#  'start_location': {'lat': 46.0248306, 'lng': 7.748230899999999},
#  'transit_details': {'arrival_stop': {'location': {'lat': 46.2939506,
#     'lng': 7.8816509},
#    'name': 'Visp'},
#   'arrival_time': {'text': '11:46am',
#    'time_zone': 'Europe/Zurich',
#    'value': 1635500760},
#   'departure_stop': {'location': {'lat': 46.0248306, 'lng': 7.748230899999999},
#    'name': 'Zermatt'},
#   'departure_time': {'text': '10:37am',
#    'time_zone': 'Europe/Zurich',
#    'value': 1635496620},
#   'headsign': 'Visp',
#   'line': {'agencies': [{'name': 'Matterhorn Gotthard Bahn (bvz)',
#      'phone': '011 41 848 642 442',
#      'url': 'https://www.matterhorngotthardbahn.ch/'}],
#    'color': '#e3081a',
#    'short_name': 'R',
#    'text_color': '#ffffff',
#    'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/ch-zurich-train.png',
#     'name': 'Train',
#     'type': 'HEAVY_RAIL'}},
#   'num_stops': 7},
#  'travel_mode': 'TRANSIT'}

# %% [markdown]
# Wir loopen durch die Schritte, um ein übersichtliches DF zu erhalten:

# %%
df = pd.DataFrame(columns=['mode', 'details', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'distance', 'duration'])


for step in route['steps']:
    
    if step['travel_mode'] == 'TRANSIT':
        mode = step['transit_details']['line']['vehicle']['name']
    else:
        mode = step['travel_mode']
    
    this_step = {
        'mode': mode,
        'details': step['html_instructions'],
        'start_lat': step['start_location']['lat'],
        'start_lng': step['start_location']['lng'],
        'end_lat': step['end_location']['lat'],
        'end_lng': step['end_location']['lng'],
        'distance': step['distance']['value'],
        'duration': step['duration']['value'],
        'polyline': step['polyline']['points']
    }
    df = df.append(this_step, ignore_index=True)

# %%
df['mode'] = df['mode'].str.lower()

# %%
df
# Out:
#                   mode                                            details  \
# 0                train                                 Train towards Visp
# 1              walking                                       Walk to Visp
# 2  long distance train             Long distance train towards Romanshorn
# 3              walking                                       Walk to Bern
# 4                train                               Train towards Luzern
# 5              walking  Walk to Murbacherstrasse 3, 6003 Luzern, Switz...
#
#    start_lat  start_lng    end_lat   end_lng distance duration  \
# 0  46.024831   7.748231  46.293951  7.881651    34904     4140
# 1  46.293939   7.881475  46.294074  7.881489       33       37
# 2  46.294049   7.882119  46.948007  7.435882    95494     3420
# 3  46.948183   7.436734  46.948558  7.436520       50       44
# 4  46.948351   7.435466  47.048468  8.310099   113005     3660
# 5  47.048470   8.310131  47.048527  8.308948      431      326
#
#                                             polyline
# 0  ef|wGmihn@@C{@k@q@c@KIKK[[QOOOGGa@a@ECQSMMKGMK...
# 1                                 cxpyGgjbo@?WK?M??T
# 2  yxpyGgnbo@?LCfBKpJK|FAl@Al@EvBElAE|@ALAPC`@?@I...
# 3                             cqp}Gqnkl@?BUFC@WH[H@F
# 4  erp}Gufkl@C@M}@g@yDE]Ie@Is@G]Ga@Om@EOMa@Se@[w@...
# 5  }cd~Giavq@aI~@Mf@BbALANCLE\Gf@Id@E^E@?\Cb@GVCX...

# %% [markdown]
# ### Geometrien erstellen

# %% [markdown]
# #### Shapeflie Kantone laden
#
# (wir brauchen das fürs crs)

# %%
gdf_kantone = gpd.read_file("dataprojects/GoogleMaps/shp/g2k17.shp", encoding='utf-8')

# %% [markdown]
# #### Startpunkt, Endpunkt

# %% [markdown]
# Punkte und GDF erstellen

# %%
df['startpoint'] = df.apply(lambda row: Point(row['start_lng'], row['start_lat']), axis=1)
df['endpoint'] = df.apply(lambda row: Point(row['end_lng'], row['end_lat']), axis=1)

# %%
gdf = gpd.GeoDataFrame(df, geometry='startpoint')

# %% [markdown]
# Koordinatensystem umrechnen

# %%
gdf.crs = {'init': 'epsg:4326'}
gdf = gdf.to_crs(gdf_kantone.crs)
# Out:
# /Users/simon/opt/anaconda3/envs/CAS-Datenjournalismus/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# Wir müssen den Schritt wiederholen, um auch den Endpunkt umzuprojizieren:

# %%
gdf = gdf.set_geometry('endpoint')

# %%
gdf.crs = {'init': 'epsg:4326'}
gdf = gdf.to_crs(gdf_kantone.crs)
# Out:
# /Users/simon/opt/anaconda3/envs/CAS-Datenjournalismus/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# #### Linie

# %% [markdown]
# Google Polyline decodieren: (https://pypi.org/project/polyline/)

# %%
gdf['line'] = gdf['polyline'].apply(lambda x: LineString(polyline.decode(x)))

# %% [markdown]
# x- und y-Koordinaten tauschen (Lat und Lng sind in der falschen Reihenfolge):

# %%
gdf['line'] = gdf['line'].map(lambda line: shapely.ops.transform(lambda x, y: (y, x), line))

# %% [markdown]
# Linie umprojizieren:

# %%
gdf = gdf.set_geometry('line')

# %%
gdf.crs = {'init': 'epsg:4326'}
gdf = gdf.to_crs(gdf_kantone.crs)
# Out:
# /Users/simon/opt/anaconda3/envs/CAS-Datenjournalismus/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# Jetzt sind wir ready.

# %%
gdf
# Out:
#                   mode                                            details  \
# 0                train                                 Train towards Visp
# 1              walking                                       Walk to Visp
# 2  long distance train             Long distance train towards Romanshorn
# 3              walking                                       Walk to Bern
# 4                train                               Train towards Luzern
# 5              walking  Walk to Murbacherstrasse 3, 6003 Luzern, Switz...
#
#    start_lat  start_lng    end_lat   end_lng distance duration  \
# 0  46.024831   7.748231  46.293951  7.881651    34904     4140
# 1  46.293939   7.881475  46.294074  7.881489       33       37
# 2  46.294049   7.882119  46.948007  7.435882    95494     3420
# 3  46.948183   7.436734  46.948558  7.436520       50       44
# 4  46.948351   7.435466  47.048468  8.310099   113005     3660
# 5  47.048470   8.310131  47.048527  8.308948      431      326
#
#                                             polyline  \
# 0  ef|wGmihn@@C{@k@q@c@KIKK[[QOOOGGa@a@ECQSMMKGMK...
# 1                                 cxpyGgjbo@?WK?M??T
# 2  yxpyGgnbo@?LCfBKpJK|FAl@Al@EvBElAE|@ALAPC`@?@I...
# 3                             cqp}Gqnkl@?BUFC@WH[H@F
# 4  erp}Gufkl@C@M}@g@yDE]Ie@Is@G]Ga@Om@EOMa@Se@[w@...
# 5  }cd~Giavq@aI~@Mf@BbALANCLE\Gf@Id@E^E@?\Cb@GVCX...
#
#                       startpoint                       endpoint  \
# 0   POINT (623973.806 97078.788)  POINT (634136.939 127044.775)
# 1  POINT (634123.431 127043.376)  POINT (634124.378 127058.434)
# 2  POINT (634172.970 127055.940)  POINT (599790.575 199658.060)
# 3  POINT (599855.454 199677.590)  POINT (599839.195 199719.358)
# 4  POINT (599758.953 199696.271)  POINT (666219.692 211193.696)
# 5  POINT (666222.083 211193.956)  POINT (666132.110 211199.273)
#
#                                                 line
# 0  LINESTRING (623973.736 97078.721, 623975.289 9...
# 1  LINESTRING (634123.777 127043.523, 634133.023 ...
# 2  LINESTRING (634173.024 127056.029, 634167.630 ...
# 3  LINESTRING (599855.165 199677.301, 599853.643 ...
# 4  LINESTRING (599759.242 199696.205, 599758.481 ...
# 5  LINESTRING (666222.030 211193.956, 666195.729 ...

# %% [markdown]
# ### Plot

# %% [markdown]
# #### Vorbereitung

# %%
color_map = {
    'walking': 'green',
    'train': 'blue',
    'tram': 'lightblue',
    'long distance train': 'darkblue',
    'driving': 'red'
}

# %%
colors = [color_map[mode] for mode in gdf['mode']]

# %%
patches = []

for mode in gdf['mode'].unique():
    this_patch = mpatches.Patch(label=mode, color=color_map[mode], alpha=0.8)
    patches.append(this_patch)

# %% [markdown]
# #### Der eigentliche Plot

# %%
# Hintergrundkarte
ax = gdf_kantone.plot(figsize=(18,10), color='lightgrey', edgecolor='white')

# Strecken
gdf.plot(ax=ax, linewidth=1.5, color=colors, alpha=0.8)

# Startpunkte
gdf.set_geometry('startpoint').plot(ax=ax, color='black', markersize=20, alpha=0.8)

# Legende
plt.legend(handles=patches, loc=1)

ax.set_title("Travelling from " + origin + " to MAZ.")
# Out:
# Text(0.5, 1.0, 'Travelling from Zermatt, Switzerland to MAZ.')
