# %%
import requests

# %%
baseurl = "https://standortcheck.mobiliar.ch/de/rating/?plz="
plz = "9043"
allplz = range(1000,9659)
mobiliar = []
for plz in allplz:
    mobiliar.append(baseurl+str(plz))

# %%
plz_resultate = []
for url in mobiliar:
    
    html_code_plz = requests.get(get) 
    plz_resultate.append(html_code_plz)

# %%
mobiliar
# Out:
# ['https://standortcheck.mobiliar.ch/de/rating/?plz=1000',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1001',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1002',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1003',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1004',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1005',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1006',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1007',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1008',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1009',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1010',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1011',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1012',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1013',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1014',
#  'https://standortcheck.mobiliar.ch/de/rating/?plz=1015',
# ...
